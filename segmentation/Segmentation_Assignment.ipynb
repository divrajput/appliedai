# %% [markdown]
# # Segmentation of Indian Traffic

# %%
import math
from PIL import Image, ImageDraw
from PIL import ImagePath
import pandas as pd
import os
from os import path
# from tqdm import tqdm
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt
import urllib
import regex as re
import tensorflow as tf

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-2-17bb7203622b>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
 print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# import zipfile
# path = r'C:\Users\divya\PycharmProjects\Applied_ai\segmentation\data.zip'
# unzip_path = r'C:\Users\divya\PycharmProjects\Applied_ai\segmentation'
# with zipfile.ZipFile(path, 'r') as zip_ref:
#     zip_ref.extractall(unzip_path)

root_dir = r'data'
os.chdir('C:\\Users\\divya\\PycharmProjects\\Applied_ai\\segmentation')
parent_dir = os.getcwd()
parent_dir
# Out:
# 'C:\\Users\\divya\\PycharmProjects\\Applied_ai\\segmentation'

# %%
# path.isfile(root_dir + '/' + 'mask' + '/' + '201' + '/' + 'frame0029_gtFine_polygons.json')
os.path.exists(root_dir + '/' + 'mask' + '/' + '201' + '/' + 'frame0029_gtFine_polygons.json')
# Out:
# True

# %% [markdown]
# <pre>
# 1. You can download the data from this link, and extract it
#
# 2. All your data will be in the folder "data"
#
# 3. Inside the data you will be having two folders
#
# |--- data
# |-----| ---- images
# |-----| ------|----- Scene 1
# |-----| ------|--------| ----- Frame 1 (image 1)
# |-----| ------|--------| ----- Frame 2 (image 2)
# |-----| ------|--------| ----- ...
# |-----| ------|----- Scene 2
# |-----| ------|--------| ----- Frame 1 (image 1)
# |-----| ------|--------| ----- Frame 2 (image 2)
# |-----| ------|--------| ----- ...
# |-----| ------|----- .....
# |-----| ---- masks
# |-----| ------|----- Scene 1
# |-----| ------|--------| ----- json 1 (labeled objects in image 1)
# |-----| ------|--------| ----- json 2 (labeled objects in image 1)
# |-----| ------|--------| ----- ...
# |-----| ------|----- Scene 2
# |-----| ------|--------| ----- json 1 (labeled objects in image 1)
# |-----| ------|--------| ----- json 2 (labeled objects in image 1)
# |-----| ------|--------| ----- ...
# |-----| ------|----- .....
# </pre>

# %% [markdown]
# # Task 1: Preprocessing

# %% [markdown]
# ## 1. Get all the file name and corresponding json files

# %%
def return_file_names_df(root_dir):
    # write the code that will create a dataframe with two columns ['images', 'json']
    # the column 'image' will have path to images
    # the column 'json' will have path to json files
    image=[]
    json = []
    for i in os.listdir(root_dir):
        if i == 'images':
            for j in os.listdir(root_dir + '/' + i):
                for k in os.listdir(root_dir + '/' + i + '/' + j):
                    image.append(root_dir + '/' + i + '/' + j + '/' + k)
        if i == 'mask':
            for j in os.listdir(root_dir + '/' + i):
                for k in os.listdir(root_dir + '/' + i + '/' + j):
                    json.append(root_dir + '/' + i + '/' + j + '/' + k)
    data = {'image':image , 'json':json}
    data_df = pd.DataFrame(data)
    return data_df

# %%
data_df = return_file_names_df(root_dir)
data_df.head()
# Out:
#                                        image  \
# 0  data/images/201/frame0029_leftImg8bit.jpg
# 1  data/images/201/frame0299_leftImg8bit.jpg
# 2  data/images/201/frame0779_leftImg8bit.jpg
# 3  data/images/201/frame1019_leftImg8bit.jpg
# 4  data/images/201/frame1469_leftImg8bit.jpg
#
#                                            json
# 0  data/mask/201/frame0029_gtFine_polygons.json
# 1  data/mask/201/frame0299_gtFine_polygons.json
# 2  data/mask/201/frame0779_gtFine_polygons.json
# 3  data/mask/201/frame1019_gtFine_polygons.json
# 4  data/mask/201/frame1469_gtFine_polygons.json

# %% [markdown]
# > If you observe the dataframe, we can consider each row as single data point, where first feature is image and the second feature is corresponding json file

# %%
def grader_1(data_df):
    for i in data_df.values:
        if not (path.isfile(i[0]) and path.isfile(i[1]) and i[0][12:i[0].find('_')]==i[1][10:i[1].find('_')]):
            return False
    return True

# %%
grader_1(data_df)
# Out:
# True

# %%
data_df.shape
# Out:
# (4008, 2)

# %% [markdown]
# ## 2. Structure of sample Json file

# %% [markdown]
# <img src='https://i.imgur.com/EfR5KmI.png' width="200" height="100">

# %% [markdown]
# * Each File will have 3 attributes
#     * imgHeight: which tells the height of the image
#     * imgWidth: which tells the width of the image
#     * objects: it is a list of objects, each object will have multiple attributes,
#         * label: the type of the object
#         * polygon: a list of two element lists, representing the coordinates of the polygon

# %% [markdown]
# #### Compute the unique labels

# %% [markdown]
# Let's see how many unique objects are there in the json file.
# to see how to get the object from the json file please check <a href='https://www.geeksforgeeks.org/read-json-file-using-python/'>this blog </a>

# %%
def return_unique_labels(data_df):
    # for each file in the column json
    #       read and store all the objects present in that file
    # compute the unique objects and retrun them
    # if open any json file using any editor you will get better sense of it
    unique_labels = []
    for json_name in data_df['json']:
        f = open(json_name)
        data = json.load(f)
        for i in data['objects']:
            unique_labels.append(i['label'])
    unique_labels = list(set(unique_labels))
    return unique_labels

# %%
unique_labels = return_unique_labels(data_df)

# %% [markdown]
# <img src='https://i.imgur.com/L4QH6Tp.png'>

# %%
label_clr = {'road':10, 'parking':20, 'drivable fallback':20,'sidewalk':30,'non-drivable fallback':40,'rail track':40,\
                        'person':50, 'animal':50, 'rider':60, 'motorcycle':70, 'bicycle':70, 'autorickshaw':80,\
                        'car':80, 'truck':90, 'bus':90, 'vehicle fallback':90, 'trailer':90, 'caravan':90,\
                        'curb':100, 'wall':100, 'fence':110,'guard rail':110, 'billboard':120,'traffic sign':120,\
                        'traffic light':120, 'pole':130, 'polegroup':130, 'obs-str-bar-fallback':130,'building':140,\
                        'bridge':140,'tunnel':140, 'vegetation':150, 'sky':160, 'fallback background':160,'unlabeled':0,\
                        'out of roi':0, 'ego vehicle':170, 'ground':180,'rectification border':190,\
                   'train':200}

# %%
def grader_2(unique_labels):
    if (not (set(label_clr.keys())-set(unique_labels))) and len(unique_labels) == 40:
        print("True")
    else:
        print("Flase")

grader_2(unique_labels)
# Out:
# True

# %% [markdown]
# <pre>
# * here we have given a number for each of object types, if you see we are having 21 different set of objects
# * Note that we have multiplies each object's number with 10, that is just to make different objects look differently in the segmentation map
# * Before you pass it to the models, you might need to devide the image array /10.
# </pre>

# %% [markdown]
# ## 3. Extracting the polygons from the json files

# %%
def get_poly(file):
    # this function will take a file name as argument
    
    # it will process all the objects in that file and returns
    
    # label: a list of labels for all the objects label[i] will have the corresponding vertices in vertexlist[i]
    # len(label) == number of objects in the image
    
    # vertexlist: it should be list of list of vertices in tuple formate 
    # ex: [[(x11,y11), (x12,y12), (x13,y13) .. (x1n,y1n)]
    #     [(x21,y21), (x22,y12), (x23,y23) .. (x2n,y2n)]
    #      .....
    #     [(xm1,ym1), (xm2,ym2), (xm3,ym3) .. (xmn,ymn)]]
    # len(vertexlist) == number of objects in the image
    
    # * note that label[i] and vertextlist[i] are corresponds to the same object, one represents the type of the object
    # the other represents the location
    
    # width of the image
    # height of the image
    f = open(file, "r")
    data = json.load(f)
    w = data['imgWidth']
    h = data['imgHeight']
    label = list()
    vertexlist = list()
    for i in data['objects']:
        if len(i['polygon'])>1:
            vertexlist.append(i['polygon'])
            label.append(i['label'])
    for i in range(len(vertexlist)):
        for j in range(len(vertexlist[i])):
            vertexlist[i][j] = tuple(vertexlist[i][j])
    return w, h, label, vertexlist

# %%
def grader_3(file):
    w, h, labels, vertexlist = get_poly(file)
    print(len((set(labels)))==18 and len(vertexlist)==227 and w==1920 and h==1080 \
          and isinstance(vertexlist,list) and isinstance(vertexlist[0],list) and isinstance(vertexlist[0][0],tuple) )

grader_3('data/mask/201/frame0029_gtFine_polygons.json')
# Out:
# True

# %% [markdown]
# ## 4. Creating Image segmentations by drawing set of polygons

# %% [markdown]
# ### Example

# %%
# import math 
# from PIL import Image, ImageDraw 
# from PIL import ImagePath  
# side=8
# x1 = [ ((math.cos(th) + 1) *9, (math.sin(th) + 1) * 6) for th in [i * (2 * math.pi) / side for i in range(side)] ]
# x2 = [ ((math.cos(th) + 2) *9, (math.sin(th) + 3) *6) for th in [i * (2 * math.pi) / side for i in range(side)] ]

# img = Image.new("RGB", (28,28))
# img1 = ImageDraw.Draw(img)
# # please play with the fill value
# # writing the first polygon
# img1.polygon(x1, fill =20)
# # writing the second polygon
# img1.polygon(x2, fill =30)

# img=np.array(img)
# # note that the filling of the values happens at the channel 1, so we are considering only the first channel here
# plt.imshow(img[:,:,0])
# print(img.shape)
# print(img[:,:,0]//10)
# im = Image.fromarray(img[:,:,0])
# im.save("test_image.png")

# %%
def compute_masks(data_df):
    # after you have computed the vertexlist plot that polygone in image like this
    
    # img = Image.new("RGB", (w, h))
    # img1 = ImageDraw.Draw(img)
    # img1.polygon(vertexlist[i], fill = label_clr[label[i]])
    
    # after drawing all the polygons that we collected from json file, 
    # you need to store that image in the folder like this "data/output/scene/framenumber_gtFine_polygons.png"
    
    # after saving the image into disk, store the path in a list
    # after storing all the paths, add a column to the data_df['mask'] ex: data_df['mask']= mask_paths
    name = data_df['json']
    mask = []
    for i in range(len(name)):
        os.chdir(parent_dir)
        w, h, label, vertexlist = get_poly(name[i])
        img = Image.new("RGB", (w,h))
        img1 = ImageDraw.Draw(img)
        for j in range(len(label)):
            img1.polygon(vertexlist[j], fill = label_clr[label[j]])
        img=np.array(img)
        im = Image.fromarray(img[:,:,0])
        file_name = re.sub('.json','.png', name[i])
        file_name = re.sub('mask','output', file_name)
        new_string = file_name.split('/')
        img_name = str(new_string[-1])
        new_string.pop(-1)
        directory_name = parent_dir + '\\' + str('\\'.join(new_string)) 
        if not os.path.isdir(directory_name):
            os.makedirs(directory_name)
        os.chdir(directory_name)
        im.save(img_name)
        mask.append(file_name)
    data_df['mask'] = mask
    os.chdir(parent_dir)
    return data_df

# %%
data_df = compute_masks(data_df)
data_df.head()
# Out:
#                                        image  \
# 0  data/images/201/frame0029_leftImg8bit.jpg
# 1  data/images/201/frame0299_leftImg8bit.jpg
# 2  data/images/201/frame0779_leftImg8bit.jpg
# 3  data/images/201/frame1019_leftImg8bit.jpg
# 4  data/images/201/frame1469_leftImg8bit.jpg
#
#                                            json  \
# 0  data/mask/201/frame0029_gtFine_polygons.json
# 1  data/mask/201/frame0299_gtFine_polygons.json
# 2  data/mask/201/frame0779_gtFine_polygons.json
# 3  data/mask/201/frame1019_gtFine_polygons.json
# 4  data/mask/201/frame1469_gtFine_polygons.json
#
#                                             mask
# 0  data/output/201/frame0029_gtFine_polygons.png
# 1  data/output/201/frame0299_gtFine_polygons.png
# 2  data/output/201/frame0779_gtFine_polygons.png
# 3  data/output/201/frame1019_gtFine_polygons.png
# 4  data/output/201/frame1469_gtFine_polygons.png

# %%
#daving the final dataframe to a csv file
data_df.to_csv('preprocessed_data.csv', index=False)

# %% [markdown]
# # Task 2: Applying Unet to segment the images

# %% [markdown]
# <pre>
# * please check the paper: https://arxiv.org/abs/1505.04597
#
# * <img src='https://i.imgur.com/rD4yP7J.jpg' width="500">
#
# * As a part of this assignment we won't writingt this whole architecture, rather we will be doing transfer learning
#
# * please check the library <a hreaf='https://github.com/qubvel/segmentation_models'>https://github.com/qubvel/segmentation_models</a>
#
# * You can install it like this "pip install -U segmentation-models==0.2.1", even in google colab you can install the    same with "!pip install -U segmentation-models==0.2.1"
#
# * Check the reference notebook in which we have solved one end to end case study of image forgery detection using same  unet
#
# * The number of channels in the output will depend on the number of classes in your data, since we know that we are having 21 classes, the number of channels in the output will also be 21
#
# * <strong>This is where we want you to explore, how do you featurize your created segmentation map note that the original map will be of (w, h, 1) and the output will be (w, h, 21) how will you calculate the loss</strong>, you can check the examples in segmentation github
#
# * please use the loss function that is used in the refence notebooks
#
# </pre>

# %% [markdown]
# ### Task 2.1: Dice loss

# %% [markdown]
# <pre>
# * Explain the Dice loss
# * 1. Write the formualtion
# * 2. Range of the loss function
# * 3. Interpretation of loss function
# * 4. Write your understanding of the loss function, how does it helps in segmentation
# </pre>

# %% [markdown]
# ### Task 2.2: Training Unet

# %% [markdown]
# <pre>
# * Split the data into 80:20.
# * Train the UNET on the given dataset and plot the train and validation loss.
# * As shown in the reference notebook plot 20 images from the test data along with its segmentation map, predicted map.
# </pre>

# %%
data_df = pd.read_csv('preprocessed_data.csv')
data_df.head()
# Out:
#                                        image  \
# 0  data/images/201/frame0029_leftImg8bit.jpg
# 1  data/images/201/frame0299_leftImg8bit.jpg
# 2  data/images/201/frame0779_leftImg8bit.jpg
# 3  data/images/201/frame1019_leftImg8bit.jpg
# 4  data/images/201/frame1469_leftImg8bit.jpg
#
#                                            json  \
# 0  data/mask/201/frame0029_gtFine_polygons.json
# 1  data/mask/201/frame0299_gtFine_polygons.json
# 2  data/mask/201/frame0779_gtFine_polygons.json
# 3  data/mask/201/frame1019_gtFine_polygons.json
# 4  data/mask/201/frame1469_gtFine_polygons.json
#
#                                             mask
# 0  data/output/201/frame0029_gtFine_polygons.png
# 1  data/output/201/frame0299_gtFine_polygons.png
# 2  data/output/201/frame0779_gtFine_polygons.png
# 3  data/output/201/frame1019_gtFine_polygons.png
# 4  data/output/201/frame1469_gtFine_polygons.png

# %%
len(data_df)
# Out:
# 4008

# %%
import tensorflow as tf
# tf.enable_eager_execution()
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# from hilbert import hilbertCurve
import imgaug.augmenters as iaa
import numpy as np
# import albumentations as A
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Multiply
from keras.callbacks import ModelCheckpoint 
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# WARNING:tensorflow:From <ipython-input-8-2f27166ccff6>:2: experimental_run_functions_eagerly (from tensorflow.python.eager.def_function) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.run_functions_eagerly` instead of the experimental version.
# WARNING:tensorflow:From <ipython-input-8-2f27166ccff6>:18: set_learning_phase (from tensorflow.python.keras.backend) is deprecated and will be removed after 2020-10-11.
# Instructions for updating:
# Simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(data_df, test_size=0.2, random_state=42)

# %%
# !pip install -U segmentation-models

# %%
import os
os.environ['SM_FRAMEWORK'] = 'tf.keras'
import segmentation_models as sm
from segmentation_models import Unet
print('sm.version=' + sm.__version__)
sm.set_framework('tf.keras')
tf.keras.backend.set_image_data_format('channels_last')
# Out:
# Segmentation Models: using `tf.keras` framework.
# sm.version=1.0.1

# %%
classes=np.arange(0,21,1)
num_classes = len(classes)
BATCH_SIZE = 8
shape_img = (256,256,3)

# %%
aug2 = iaa.Fliplr(1)
aug3 = iaa.Flipud(1)
aug4 = iaa.Emboss(alpha=(1), strength=1)
aug5 = iaa.DirectedEdgeDetect(alpha=(0.8), direction=(1.0))
aug6 = iaa.Sharpen(alpha=(1.0), lightness=(1.5))

# %%
def visualize(**images):
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        if i==1:
            plt.imshow(image, cmap='gray', vmax=1, vmin=0)
        else:
            plt.imshow(image)
    plt.show()
    
def normalize_image(mask):
    mask = mask/255
    return mask

class Dataset:
    # we will be modifying this CLASSES according to your data/problems
    CLASSES = np.arange(0,21,1)
    
    # the parameters needs to changed based on your requirements
    # here we are collecting the file_names because in our dataset, both our images and maks will have same file name
    # ex: fil_name.jpg   file_name.mask.jpg
    def __init__(self, file_names, classes = None):
        
        self.ids = file_names
        # the paths of images
        self.images_fps   = [image_path for image_path in file_names['image']]
        # the paths of segmentation images
        self.masks_fps    = [image_path for image_path in file_names['mask']]
        # giving labels for each class
        self.class_values = classes
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i], cv2.IMREAD_UNCHANGED) 
        image = cv2.resize(image,(256,256),interpolation=cv2.INTER_AREA)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        mask  = cv2.imread(self.masks_fps[i], cv2.IMREAD_UNCHANGED)
        mask = cv2.resize(mask,(256,256),interpolation=cv2.INTER_AREA)
        image_mask = mask / 10

        
        image_masks = [(image_mask == v) for v in self.class_values]
        image_mask = np.stack(image_masks, axis=-1).astype('float')
   
        a = np.random.uniform()
        if a<0.2:
            image = image
            image_mask = image_mask
        elif a<0.4:
            image = aug3.augment_image(image)
            image_mask = aug3.augment_image(image_mask)
        elif a<0.6:
            image = aug4.augment_image(image)
            image_mask = aug4.augment_image(image_mask)
        elif a<0.8:
            image = aug5.augment_image(image)
            image_mask = image_mask
        else:
            image = aug6.augment_image(image)
            image_mask = aug6.augment_image(image_mask)
            
        return image, image_mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(tf.keras.utils.Sequence):    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return tuple(batch)
    
    def __len__(self):
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Dataset for train images
CLASSES = np.arange(0,21,1)
train_dataset = Dataset(train_df, classes=CLASSES)
test_dataset  = Dataset(test_df, classes=CLASSES)


train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = Dataloder(test_dataset, batch_size=BATCH_SIZE, shuffle=True)

print(train_dataloader[0][0].shape)
print(train_dataloader[0][1].shape)
assert train_dataloader[0][0].shape == (BATCH_SIZE, 256, 256, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 256, 256, 21)
# Out:
# (8, 256, 256, 3)
# (8, 256, 256, 21)

# %%
# loading the unet model and using the resnet 34 and initilized weights with imagenet weights
# "classes" :different types of classes in the dataset
model = Unet('resnet34', encoder_weights='imagenet', classes=num_classes, activation='sigmoid', input_shape=shape_img)

# %%
model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 256, 256, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 128, 128, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 128, 128, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 128, 128, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 130, 130, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 64, 64, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 64, 64, 64)   256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 64, 64, 64)   4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 64)   0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 64, 64, 64)   256         add_12[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 64, 64, 64)   0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 64)   0           stage1_unit2_conv2[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 64, 64, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 64, 64, 64)   0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 64)   0           stage1_unit3_conv2[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 64, 64, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 64, 64, 64)   0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 66, 66, 64)   0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 32, 32, 128)  73728       zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 34, 34, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 32, 32, 128)  8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 128)  0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 32, 32, 128)  512         add_15[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 32, 32, 128)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 34, 34, 128)  0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 34, 34, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 128)  0           stage2_unit2_conv2[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, 32, 32, 128)  512         add_16[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, 32, 32, 128)  0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 34, 34, 128)  0           stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 34, 34, 128)  0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 32, 32, 128)  0           stage2_unit3_conv2[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, 32, 32, 128)  512         add_17[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, 32, 32, 128)  0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 34, 34, 128)  0           stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 34, 34, 128)  0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 128)  0           stage2_unit4_conv2[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 32, 32, 128)  512         add_18[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 32, 32, 128)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 34, 34, 128)  0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 16, 16, 256)  294912      zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 16, 16, 256)  32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 16, 256)  0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 16, 16, 256)  1024        add_19[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 16, 16, 256)  0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 16, 256)  0           stage3_unit2_conv2[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, 16, 16, 256)  1024        add_20[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, 16, 16, 256)  0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 16, 256)  0           stage3_unit3_conv2[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, 16, 16, 256)  1024        add_21[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, 16, 16, 256)  0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 256)  0           stage3_unit4_conv2[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, 16, 16, 256)  1024        add_22[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, 16, 16, 256)  0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 256)  0           stage3_unit5_conv2[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, 16, 16, 256)  1024        add_23[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, 16, 16, 256)  0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_26[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 256)  0           stage3_unit6_conv2[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 16, 16, 256)  1024        add_24[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 16, 16, 256)  0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 18, 18, 256)  0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 8, 8, 512)    1179648     zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 8, 8, 512)    0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_29[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 8, 8, 512)    131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 512)    0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 8, 8, 512)    2048        add_25[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 8, 8, 512)    0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 8, 8, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 512)    0           stage4_unit2_conv2[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, 8, 8, 512)    2048        add_26[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, 8, 8, 512)    0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 8, 8, 512)    0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_33[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 512)    0           stage4_unit3_conv2[0][0]
#                                                                  add_26[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 8, 8, 512)    2048        add_27[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 8, 8, 512)    0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 16, 16, 512)  0           relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 16, 16, 768)  0           decoder_stage0_upsampling[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, 16, 16, 256)  1769472     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 16, 16, 256)  1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 16, 16, 256)  0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, 16, 16, 256)  589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 16, 16, 256)  1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 16, 16, 256)  0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 32, 32, 256)  0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 32, 32, 384)  0           decoder_stage1_upsampling[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, 32, 32, 128)  442368      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 32, 32, 128)  512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 32, 32, 128)  0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, 32, 32, 128)  147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 32, 32, 128)  512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 32, 32, 128)  0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 64, 64, 128)  0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 64, 64, 192)  0           decoder_stage2_upsampling[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, 64, 64, 64)   110592      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 64, 64, 64)   256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 64, 64, 64)   0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, 64, 64, 64)   36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 64, 64, 64)   256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 64, 64, 64)   0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 128, 128, 64) 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 128, 128, 128 0           decoder_stage3_upsampling[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, 128, 128, 32) 36864       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 128, 128, 32) 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 128, 128, 32) 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, 128, 128, 32) 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 128, 128, 32) 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 128, 128, 32) 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 256, 256, 32) 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, 256, 256, 16) 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 256, 256, 16) 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 256, 256, 16) 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, 256, 256, 16) 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 256, 256, 16) 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 256, 256, 16) 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 256, 256, 21) 3045        decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 256, 256, 21) 0           final_conv[0][0]
# ==================================================================================================
# Total params: 24,459,054
# Trainable params: 24,441,704
# Non-trainable params: 17,350
# __________________________________________________________________________________________________

# %%
# https://github.com/qubvel/segmentation_models
import segmentation_models as sm
from segmentation_models.metrics import iou_score
from segmentation_models import Unet
from tensorflow.keras.optimizers import Adam
from keras.optimizers import TFOptimizer
# from keras import backend as K
# learning_rate = K.variable(0.0001)
optim = tf.keras.optimizers.Adam(lr = 0.0001)
# optim= TFOptimizer(adamW)
# optim.lr = learning_rate

focal_loss = sm.losses.cce_dice_loss

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss 
# or total_loss = sm.losses.categorical_focal_dice_loss 

model.compile(optimizer=optim, loss = focal_loss, metrics=[iou_score])

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint('./best_unet_model.h5', save_weights_only=True, save_best_only=True, \
                                       mode='min', monitor='val_iou_score'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_iou_score', min_lr=0.000001,patience=2),
]

# %%
history = model.fit_generator(train_dataloader, steps_per_epoch=len(train_dataloader), epochs=500,\
                              validation_data=test_dataloader,callbacks=callbacks )
# Out:
# WARNING:tensorflow:From C:\Users\divya\AppData\Local\Temp\ipykernel_6296\4007302423.py:2: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/500
# 400/400 [==============================] - 270s 674ms/step - loss: 0.9607 - iou_score: 0.0990 - val_loss: 0.8927 - val_iou_score: 0.1310 - lr: 1.0000e-04
# Epoch 2/500
# 400/400 [==============================] - 268s 669ms/step - loss: 0.8045 - iou_score: 0.1850 - val_loss: 0.7536 - val_iou_score: 0.2180 - lr: 1.0000e-04
# Epoch 3/500
# 400/400 [==============================] - 268s 670ms/step - loss: 0.7141 - iou_score: 0.2477 - val_loss: 0.6837 - val_iou_score: 0.2725 - lr: 1.0000e-04
# Epoch 4/500
# 400/400 [==============================] - 270s 674ms/step - loss: 0.6612 - iou_score: 0.2896 - val_loss: 0.6508 - val_iou_score: 0.2982 - lr: 1.0000e-05
# Epoch 5/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.6490 - iou_score: 0.2997 - val_loss: 0.6471 - val_iou_score: 0.3014 - lr: 1.0000e-05
# Epoch 6/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.6422 - iou_score: 0.3052 - val_loss: 0.6467 - val_iou_score: 0.3006 - lr: 1.0000e-06
# Epoch 7/500
# 400/400 [==============================] - 271s 676ms/step - loss: 0.6425 - iou_score: 0.3045 - val_loss: 0.6450 - val_iou_score: 0.3027 - lr: 1.0000e-06
# Epoch 8/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.6417 - iou_score: 0.3055 - val_loss: 0.6404 - val_iou_score: 0.3072 - lr: 1.0000e-06
# Epoch 9/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.6395 - iou_score: 0.3081 - val_loss: 0.6411 - val_iou_score: 0.3074 - lr: 1.0000e-06
# Epoch 10/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.6387 - iou_score: 0.3089 - val_loss: 0.6411 - val_iou_score: 0.3074 - lr: 1.0000e-06
# Epoch 11/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.6366 - iou_score: 0.3105 - val_loss: 0.6407 - val_iou_score: 0.3067 - lr: 1.0000e-06
# Epoch 12/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.6337 - iou_score: 0.3139 - val_loss: 0.6423 - val_iou_score: 0.3047 - lr: 1.0000e-06
# Epoch 13/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.6359 - iou_score: 0.3106 - val_loss: 0.6384 - val_iou_score: 0.3098 - lr: 1.0000e-06
# Epoch 14/500
# 400/400 [==============================] - 271s 679ms/step - loss: 0.6348 - iou_score: 0.3125 - val_loss: 0.6415 - val_iou_score: 0.3062 - lr: 1.0000e-06
# Epoch 15/500
# 400/400 [==============================] - 272s 679ms/step - loss: 0.6333 - iou_score: 0.3139 - val_loss: 0.6427 - val_iou_score: 0.3039 - lr: 1.0000e-06
# Epoch 16/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.6334 - iou_score: 0.3128 - val_loss: 0.6411 - val_iou_score: 0.3047 - lr: 1.0000e-06
# Epoch 17/500
# 400/400 [==============================] - 273s 681ms/step - loss: 0.6329 - iou_score: 0.3139 - val_loss: 0.6408 - val_iou_score: 0.3066 - lr: 1.0000e-06
# Epoch 18/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.6311 - iou_score: 0.3156 - val_loss: 0.6383 - val_iou_score: 0.3094 - lr: 1.0000e-06
# Epoch 19/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.6318 - iou_score: 0.3151 - val_loss: 0.6336 - val_iou_score: 0.3146 - lr: 1.0000e-06
# Epoch 20/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.6297 - iou_score: 0.3168 - val_loss: 0.6359 - val_iou_score: 0.3118 - lr: 1.0000e-06
# Epoch 21/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.6293 - iou_score: 0.3170 - val_loss: 0.6382 - val_iou_score: 0.3092 - lr: 1.0000e-06
# Epoch 22/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.6280 - iou_score: 0.3180 - val_loss: 0.6360 - val_iou_score: 0.3110 - lr: 1.0000e-06
# Epoch 23/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.6274 - iou_score: 0.3184 - val_loss: 0.6359 - val_iou_score: 0.3112 - lr: 1.0000e-06
# Epoch 24/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.6270 - iou_score: 0.3183 - val_loss: 0.6346 - val_iou_score: 0.3129 - lr: 1.0000e-06
# Epoch 25/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.6260 - iou_score: 0.3200 - val_loss: 0.6285 - val_iou_score: 0.3194 - lr: 1.0000e-06
# Epoch 26/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.6235 - iou_score: 0.3225 - val_loss: 0.6293 - val_iou_score: 0.3196 - lr: 1.0000e-06
# Epoch 27/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.6244 - iou_score: 0.3212 - val_loss: 0.6354 - val_iou_score: 0.3115 - lr: 1.0000e-06
# Epoch 28/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.6213 - iou_score: 0.3249 - val_loss: 0.6336 - val_iou_score: 0.3147 - lr: 1.0000e-06
# Epoch 29/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.6228 - iou_score: 0.3227 - val_loss: 0.6318 - val_iou_score: 0.3147 - lr: 1.0000e-06
# Epoch 30/500
# 400/400 [==============================] - 275s 686ms/step - loss: 0.6214 - iou_score: 0.3243 - val_loss: 0.6319 - val_iou_score: 0.3160 - lr: 1.0000e-06
# Epoch 31/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.6210 - iou_score: 0.3247 - val_loss: 0.6288 - val_iou_score: 0.3188 - lr: 1.0000e-06
# Epoch 32/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.6191 - iou_score: 0.3265 - val_loss: 0.6320 - val_iou_score: 0.3145 - lr: 1.0000e-06
# Epoch 33/500
# 400/400 [==============================] - 273s 684ms/step - loss: 0.6209 - iou_score: 0.3243 - val_loss: 0.6294 - val_iou_score: 0.3173 - lr: 1.0000e-06
# Epoch 34/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.6178 - iou_score: 0.3279 - val_loss: 0.6283 - val_iou_score: 0.3201 - lr: 1.0000e-06
# Epoch 35/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.6189 - iou_score: 0.3261 - val_loss: 0.6293 - val_iou_score: 0.3165 - lr: 1.0000e-06
# Epoch 36/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.6186 - iou_score: 0.3263 - val_loss: 0.6271 - val_iou_score: 0.3192 - lr: 1.0000e-06
# Epoch 37/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.6176 - iou_score: 0.3273 - val_loss: 0.6287 - val_iou_score: 0.3180 - lr: 1.0000e-06
# Epoch 38/500
# 400/400 [==============================] - 281s 703ms/step - loss: 0.6177 - iou_score: 0.3268 - val_loss: 0.6232 - val_iou_score: 0.3232 - lr: 1.0000e-06
# Epoch 39/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.6154 - iou_score: 0.3291 - val_loss: 0.6279 - val_iou_score: 0.3189 - lr: 1.0000e-06
# Epoch 40/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.6144 - iou_score: 0.3303 - val_loss: 0.6268 - val_iou_score: 0.3197 - lr: 1.0000e-06
# Epoch 41/500
# 400/400 [==============================] - 273s 684ms/step - loss: 0.6151 - iou_score: 0.3290 - val_loss: 0.6266 - val_iou_score: 0.3207 - lr: 1.0000e-06
# Epoch 42/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.6141 - iou_score: 0.3301 - val_loss: 0.6213 - val_iou_score: 0.3252 - lr: 1.0000e-06
# Epoch 43/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.6135 - iou_score: 0.3309 - val_loss: 0.6238 - val_iou_score: 0.3224 - lr: 1.0000e-06
# Epoch 44/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.6119 - iou_score: 0.3327 - val_loss: 0.6218 - val_iou_score: 0.3253 - lr: 1.0000e-06
# Epoch 45/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.6111 - iou_score: 0.3334 - val_loss: 0.6232 - val_iou_score: 0.3236 - lr: 1.0000e-06
# Epoch 46/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.6112 - iou_score: 0.3328 - val_loss: 0.6189 - val_iou_score: 0.3278 - lr: 1.0000e-06
# Epoch 47/500
# 400/400 [==============================] - 273s 684ms/step - loss: 0.6103 - iou_score: 0.3337 - val_loss: 0.6240 - val_iou_score: 0.3236 - lr: 1.0000e-06
# Epoch 48/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.6104 - iou_score: 0.3336 - val_loss: 0.6219 - val_iou_score: 0.3244 - lr: 1.0000e-06
# Epoch 49/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.6103 - iou_score: 0.3334 - val_loss: 0.6229 - val_iou_score: 0.3233 - lr: 1.0000e-06
# Epoch 50/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.6066 - iou_score: 0.3377 - val_loss: 0.6226 - val_iou_score: 0.3246 - lr: 1.0000e-06
# Epoch 51/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.6084 - iou_score: 0.3351 - val_loss: 0.6216 - val_iou_score: 0.3246 - lr: 1.0000e-06
# Epoch 52/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.6062 - iou_score: 0.3381 - val_loss: 0.6183 - val_iou_score: 0.3285 - lr: 1.0000e-06
# Epoch 53/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.6058 - iou_score: 0.3375 - val_loss: 0.6187 - val_iou_score: 0.3283 - lr: 1.0000e-06
# Epoch 54/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.6052 - iou_score: 0.3385 - val_loss: 0.6186 - val_iou_score: 0.3273 - lr: 1.0000e-06
# Epoch 55/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.6042 - iou_score: 0.3388 - val_loss: 0.6193 - val_iou_score: 0.3267 - lr: 1.0000e-06
# Epoch 56/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.6027 - iou_score: 0.3413 - val_loss: 0.6235 - val_iou_score: 0.3221 - lr: 1.0000e-06
# Epoch 57/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.6030 - iou_score: 0.3395 - val_loss: 0.6189 - val_iou_score: 0.3281 - lr: 1.0000e-06
# Epoch 58/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.6019 - iou_score: 0.3414 - val_loss: 0.6167 - val_iou_score: 0.3293 - lr: 1.0000e-06
# Epoch 59/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.6023 - iou_score: 0.3413 - val_loss: 0.6127 - val_iou_score: 0.3340 - lr: 1.0000e-06
# Epoch 60/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5997 - iou_score: 0.3438 - val_loss: 0.6179 - val_iou_score: 0.3273 - lr: 1.0000e-06
# Epoch 61/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.5993 - iou_score: 0.3439 - val_loss: 0.6163 - val_iou_score: 0.3294 - lr: 1.0000e-06
# Epoch 62/500
# 400/400 [==============================] - 286s 714ms/step - loss: 0.5990 - iou_score: 0.3446 - val_loss: 0.6164 - val_iou_score: 0.3292 - lr: 1.0000e-06
# Epoch 63/500
# 400/400 [==============================] - 356s 890ms/step - loss: 0.5997 - iou_score: 0.3434 - val_loss: 0.6168 - val_iou_score: 0.3289 - lr: 1.0000e-06
# Epoch 64/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5975 - iou_score: 0.3460 - val_loss: 0.6183 - val_iou_score: 0.3272 - lr: 1.0000e-06
# Epoch 65/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.5962 - iou_score: 0.3470 - val_loss: 0.6164 - val_iou_score: 0.3289 - lr: 1.0000e-06
# Epoch 66/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.5964 - iou_score: 0.3466 - val_loss: 0.6163 - val_iou_score: 0.3297 - lr: 1.0000e-06
# Epoch 67/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.5977 - iou_score: 0.3450 - val_loss: 0.6157 - val_iou_score: 0.3295 - lr: 1.0000e-06
# Epoch 68/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.5947 - iou_score: 0.3483 - val_loss: 0.6198 - val_iou_score: 0.3251 - lr: 1.0000e-06
# Epoch 69/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5938 - iou_score: 0.3486 - val_loss: 0.6132 - val_iou_score: 0.3327 - lr: 1.0000e-06
# Epoch 70/500
# 400/400 [==============================] - 269s 673ms/step - loss: 0.5934 - iou_score: 0.3497 - val_loss: 0.6092 - val_iou_score: 0.3358 - lr: 1.0000e-06
# Epoch 71/500
# 400/400 [==============================] - 266s 665ms/step - loss: 0.5932 - iou_score: 0.3492 - val_loss: 0.6136 - val_iou_score: 0.3303 - lr: 1.0000e-06
# Epoch 72/500
# 400/400 [==============================] - 268s 670ms/step - loss: 0.5923 - iou_score: 0.3502 - val_loss: 0.6151 - val_iou_score: 0.3299 - lr: 1.0000e-06
# Epoch 73/500
# 400/400 [==============================] - 267s 667ms/step - loss: 0.5884 - iou_score: 0.3545 - val_loss: 0.6099 - val_iou_score: 0.3368 - lr: 1.0000e-06
# Epoch 74/500
# 400/400 [==============================] - 284s 709ms/step - loss: 0.5894 - iou_score: 0.3533 - val_loss: 0.6116 - val_iou_score: 0.3352 - lr: 1.0000e-06
# Epoch 75/500
# 400/400 [==============================] - 277s 691ms/step - loss: 0.5913 - iou_score: 0.3510 - val_loss: 0.6082 - val_iou_score: 0.3373 - lr: 1.0000e-06
# Epoch 76/500
# 400/400 [==============================] - 264s 661ms/step - loss: 0.5903 - iou_score: 0.3519 - val_loss: 0.6116 - val_iou_score: 0.3332 - lr: 1.0000e-06
# Epoch 77/500
# 400/400 [==============================] - 268s 669ms/step - loss: 0.5887 - iou_score: 0.3534 - val_loss: 0.6094 - val_iou_score: 0.3353 - lr: 1.0000e-06
# Epoch 78/500
# 400/400 [==============================] - 267s 666ms/step - loss: 0.5881 - iou_score: 0.3539 - val_loss: 0.6106 - val_iou_score: 0.3346 - lr: 1.0000e-06
# Epoch 79/500
# 400/400 [==============================] - 279s 698ms/step - loss: 0.5869 - iou_score: 0.3550 - val_loss: 0.6094 - val_iou_score: 0.3363 - lr: 1.0000e-06
# Epoch 80/500
# 400/400 [==============================] - 279s 698ms/step - loss: 0.5852 - iou_score: 0.3567 - val_loss: 0.6085 - val_iou_score: 0.3365 - lr: 1.0000e-06
# Epoch 81/500
# 400/400 [==============================] - 279s 697ms/step - loss: 0.5856 - iou_score: 0.3558 - val_loss: 0.6088 - val_iou_score: 0.3353 - lr: 1.0000e-06
# Epoch 82/500
# 400/400 [==============================] - 281s 702ms/step - loss: 0.5845 - iou_score: 0.3567 - val_loss: 0.6078 - val_iou_score: 0.3376 - lr: 1.0000e-06
# Epoch 83/500
# 400/400 [==============================] - 292s 731ms/step - loss: 0.5871 - iou_score: 0.3537 - val_loss: 0.6040 - val_iou_score: 0.3399 - lr: 1.0000e-06
# Epoch 84/500
# 400/400 [==============================] - 290s 725ms/step - loss: 0.5846 - iou_score: 0.3568 - val_loss: 0.6035 - val_iou_score: 0.3419 - lr: 1.0000e-06
# Epoch 85/500
# 400/400 [==============================] - 295s 739ms/step - loss: 0.5826 - iou_score: 0.3592 - val_loss: 0.6082 - val_iou_score: 0.3366 - lr: 1.0000e-06
# Epoch 86/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5813 - iou_score: 0.3605 - val_loss: 0.6087 - val_iou_score: 0.3360 - lr: 1.0000e-06
# Epoch 87/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.5815 - iou_score: 0.3597 - val_loss: 0.6027 - val_iou_score: 0.3428 - lr: 1.0000e-06
# Epoch 88/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.5830 - iou_score: 0.3571 - val_loss: 0.6076 - val_iou_score: 0.3365 - lr: 1.0000e-06
# Epoch 89/500
# 400/400 [==============================] - 270s 674ms/step - loss: 0.5780 - iou_score: 0.3631 - val_loss: 0.6051 - val_iou_score: 0.3387 - lr: 1.0000e-06
# Epoch 90/500
# 400/400 [==============================] - 267s 667ms/step - loss: 0.5793 - iou_score: 0.3614 - val_loss: 0.6059 - val_iou_score: 0.3384 - lr: 1.0000e-06
# Epoch 91/500
# 400/400 [==============================] - 269s 673ms/step - loss: 0.5769 - iou_score: 0.3642 - val_loss: 0.6055 - val_iou_score: 0.3399 - lr: 1.0000e-06
# Epoch 92/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.5764 - iou_score: 0.3648 - val_loss: 0.6066 - val_iou_score: 0.3358 - lr: 1.0000e-06
# Epoch 93/500
# 400/400 [==============================] - 267s 667ms/step - loss: 0.5781 - iou_score: 0.3623 - val_loss: 0.6091 - val_iou_score: 0.3348 - lr: 1.0000e-06
# Epoch 94/500
# 400/400 [==============================] - 270s 674ms/step - loss: 0.5755 - iou_score: 0.3656 - val_loss: 0.6032 - val_iou_score: 0.3418 - lr: 1.0000e-06
# Epoch 95/500
# 400/400 [==============================] - 266s 666ms/step - loss: 0.5804 - iou_score: 0.3591 - val_loss: 0.6046 - val_iou_score: 0.3395 - lr: 1.0000e-06
# Epoch 96/500
# 400/400 [==============================] - 270s 676ms/step - loss: 0.5753 - iou_score: 0.3648 - val_loss: 0.6024 - val_iou_score: 0.3436 - lr: 1.0000e-06
# Epoch 97/500
# 400/400 [==============================] - 270s 674ms/step - loss: 0.5726 - iou_score: 0.3680 - val_loss: 0.6035 - val_iou_score: 0.3416 - lr: 1.0000e-06
# Epoch 98/500
# 400/400 [==============================] - 268s 671ms/step - loss: 0.5732 - iou_score: 0.3667 - val_loss: 0.6019 - val_iou_score: 0.3420 - lr: 1.0000e-06
# Epoch 99/500
# 400/400 [==============================] - 269s 673ms/step - loss: 0.5723 - iou_score: 0.3678 - val_loss: 0.6026 - val_iou_score: 0.3412 - lr: 1.0000e-06
# Epoch 100/500
# 400/400 [==============================] - 268s 670ms/step - loss: 0.5725 - iou_score: 0.3675 - val_loss: 0.6038 - val_iou_score: 0.3403 - lr: 1.0000e-06
# Epoch 101/500
# 400/400 [==============================] - 269s 672ms/step - loss: 0.5729 - iou_score: 0.3673 - val_loss: 0.6018 - val_iou_score: 0.3435 - lr: 1.0000e-06
# Epoch 102/500
# 400/400 [==============================] - 265s 662ms/step - loss: 0.5715 - iou_score: 0.3686 - val_loss: 0.6019 - val_iou_score: 0.3413 - lr: 1.0000e-06
# Epoch 103/500
# 400/400 [==============================] - 266s 665ms/step - loss: 0.5695 - iou_score: 0.3704 - val_loss: 0.6018 - val_iou_score: 0.3426 - lr: 1.0000e-06
# Epoch 104/500
# 400/400 [==============================] - 269s 674ms/step - loss: 0.5678 - iou_score: 0.3725 - val_loss: 0.6029 - val_iou_score: 0.3415 - lr: 1.0000e-06
# Epoch 105/500
# 400/400 [==============================] - 269s 671ms/step - loss: 0.5683 - iou_score: 0.3709 - val_loss: 0.6020 - val_iou_score: 0.3421 - lr: 1.0000e-06
# Epoch 106/500
# 400/400 [==============================] - 270s 675ms/step - loss: 0.5667 - iou_score: 0.3737 - val_loss: 0.5995 - val_iou_score: 0.3449 - lr: 1.0000e-06
# Epoch 107/500
# 400/400 [==============================] - 269s 673ms/step - loss: 0.5681 - iou_score: 0.3717 - val_loss: 0.6008 - val_iou_score: 0.3441 - lr: 1.0000e-06
# Epoch 108/500
# 400/400 [==============================] - 268s 671ms/step - loss: 0.5677 - iou_score: 0.3719 - val_loss: 0.5993 - val_iou_score: 0.3455 - lr: 1.0000e-06
# Epoch 109/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.5642 - iou_score: 0.3752 - val_loss: 0.5984 - val_iou_score: 0.3460 - lr: 1.0000e-06
# Epoch 110/500
# 400/400 [==============================] - 270s 675ms/step - loss: 0.5648 - iou_score: 0.3754 - val_loss: 0.5974 - val_iou_score: 0.3481 - lr: 1.0000e-06
# Epoch 111/500
# 400/400 [==============================] - 270s 675ms/step - loss: 0.5631 - iou_score: 0.3770 - val_loss: 0.5947 - val_iou_score: 0.3502 - lr: 1.0000e-06
# Epoch 112/500
# 400/400 [==============================] - 269s 673ms/step - loss: 0.5641 - iou_score: 0.3761 - val_loss: 0.5938 - val_iou_score: 0.3509 - lr: 1.0000e-06
# Epoch 113/500
# 400/400 [==============================] - 269s 673ms/step - loss: 0.5629 - iou_score: 0.3764 - val_loss: 0.5968 - val_iou_score: 0.3482 - lr: 1.0000e-06
# Epoch 114/500
# 400/400 [==============================] - 269s 674ms/step - loss: 0.5639 - iou_score: 0.3753 - val_loss: 0.5937 - val_iou_score: 0.3514 - lr: 1.0000e-06
# Epoch 115/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.5633 - iou_score: 0.3761 - val_loss: 0.5906 - val_iou_score: 0.3549 - lr: 1.0000e-06
# Epoch 116/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.5604 - iou_score: 0.3791 - val_loss: 0.5986 - val_iou_score: 0.3463 - lr: 1.0000e-06
# Epoch 117/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.5603 - iou_score: 0.3790 - val_loss: 0.5990 - val_iou_score: 0.3446 - lr: 1.0000e-06
# Epoch 118/500
# 400/400 [==============================] - 275s 686ms/step - loss: 0.5586 - iou_score: 0.3813 - val_loss: 0.5993 - val_iou_score: 0.3446 - lr: 1.0000e-06
# Epoch 119/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5593 - iou_score: 0.3791 - val_loss: 0.5947 - val_iou_score: 0.3500 - lr: 1.0000e-06
# Epoch 120/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.5570 - iou_score: 0.3829 - val_loss: 0.5967 - val_iou_score: 0.3464 - lr: 1.0000e-06
# Epoch 121/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.5588 - iou_score: 0.3805 - val_loss: 0.5949 - val_iou_score: 0.3487 - lr: 1.0000e-06
# Epoch 122/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5567 - iou_score: 0.3820 - val_loss: 0.5937 - val_iou_score: 0.3499 - lr: 1.0000e-06
# Epoch 123/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5573 - iou_score: 0.3818 - val_loss: 0.5918 - val_iou_score: 0.3526 - lr: 1.0000e-06
# Epoch 124/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.5563 - iou_score: 0.3830 - val_loss: 0.5953 - val_iou_score: 0.3480 - lr: 1.0000e-06
# Epoch 125/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.5561 - iou_score: 0.3829 - val_loss: 0.5905 - val_iou_score: 0.3527 - lr: 1.0000e-06
# Epoch 126/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.5557 - iou_score: 0.3830 - val_loss: 0.5964 - val_iou_score: 0.3482 - lr: 1.0000e-06
# Epoch 127/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5540 - iou_score: 0.3844 - val_loss: 0.5898 - val_iou_score: 0.3534 - lr: 1.0000e-06
# Epoch 128/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5541 - iou_score: 0.3847 - val_loss: 0.5912 - val_iou_score: 0.3523 - lr: 1.0000e-06
# Epoch 129/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5530 - iou_score: 0.3859 - val_loss: 0.5907 - val_iou_score: 0.3548 - lr: 1.0000e-06
# Epoch 130/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5523 - iou_score: 0.3860 - val_loss: 0.5888 - val_iou_score: 0.3557 - lr: 1.0000e-06
# Epoch 131/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.5543 - iou_score: 0.3844 - val_loss: 0.5906 - val_iou_score: 0.3537 - lr: 1.0000e-06
# Epoch 132/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5514 - iou_score: 0.3873 - val_loss: 0.5912 - val_iou_score: 0.3523 - lr: 1.0000e-06
# Epoch 133/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5478 - iou_score: 0.3912 - val_loss: 0.5986 - val_iou_score: 0.3450 - lr: 1.0000e-06
# Epoch 134/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5490 - iou_score: 0.3893 - val_loss: 0.5946 - val_iou_score: 0.3490 - lr: 1.0000e-06
# Epoch 135/500
# 400/400 [==============================] - 275s 686ms/step - loss: 0.5517 - iou_score: 0.3869 - val_loss: 0.5890 - val_iou_score: 0.3553 - lr: 1.0000e-06
# Epoch 136/500
# 400/400 [==============================] - 277s 691ms/step - loss: 0.5501 - iou_score: 0.3882 - val_loss: 0.5881 - val_iou_score: 0.3553 - lr: 1.0000e-06
# Epoch 137/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5475 - iou_score: 0.3917 - val_loss: 0.5901 - val_iou_score: 0.3533 - lr: 1.0000e-06
# Epoch 138/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5482 - iou_score: 0.3906 - val_loss: 0.5881 - val_iou_score: 0.3554 - lr: 1.0000e-06
# Epoch 139/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.5470 - iou_score: 0.3921 - val_loss: 0.5900 - val_iou_score: 0.3542 - lr: 1.0000e-06
# Epoch 140/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.5469 - iou_score: 0.3911 - val_loss: 0.5881 - val_iou_score: 0.3568 - lr: 1.0000e-06
# Epoch 141/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5446 - iou_score: 0.3936 - val_loss: 0.5882 - val_iou_score: 0.3555 - lr: 1.0000e-06
# Epoch 142/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.5448 - iou_score: 0.3937 - val_loss: 0.5870 - val_iou_score: 0.3571 - lr: 1.0000e-06
# Epoch 143/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.5446 - iou_score: 0.3941 - val_loss: 0.5899 - val_iou_score: 0.3536 - lr: 1.0000e-06
# Epoch 144/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5444 - iou_score: 0.3939 - val_loss: 0.5907 - val_iou_score: 0.3526 - lr: 1.0000e-06
# Epoch 145/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5432 - iou_score: 0.3962 - val_loss: 0.5856 - val_iou_score: 0.3576 - lr: 1.0000e-06
# Epoch 146/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5428 - iou_score: 0.3964 - val_loss: 0.5897 - val_iou_score: 0.3539 - lr: 1.0000e-06
# Epoch 147/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.5422 - iou_score: 0.3963 - val_loss: 0.5902 - val_iou_score: 0.3523 - lr: 1.0000e-06
# Epoch 148/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.5397 - iou_score: 0.3993 - val_loss: 0.5877 - val_iou_score: 0.3549 - lr: 1.0000e-06
# Epoch 149/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.5403 - iou_score: 0.3985 - val_loss: 0.5914 - val_iou_score: 0.3528 - lr: 1.0000e-06
# Epoch 150/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5408 - iou_score: 0.3979 - val_loss: 0.5889 - val_iou_score: 0.3550 - lr: 1.0000e-06
# Epoch 151/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5401 - iou_score: 0.3980 - val_loss: 0.5882 - val_iou_score: 0.3568 - lr: 1.0000e-06
# Epoch 152/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.5391 - iou_score: 0.3991 - val_loss: 0.5942 - val_iou_score: 0.3498 - lr: 1.0000e-06
# Epoch 153/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5398 - iou_score: 0.3984 - val_loss: 0.5865 - val_iou_score: 0.3572 - lr: 1.0000e-06
# Epoch 154/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.5386 - iou_score: 0.3997 - val_loss: 0.5885 - val_iou_score: 0.3554 - lr: 1.0000e-06
# Epoch 155/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.5394 - iou_score: 0.3987 - val_loss: 0.5883 - val_iou_score: 0.3554 - lr: 1.0000e-06
# Epoch 156/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5340 - iou_score: 0.4052 - val_loss: 0.5890 - val_iou_score: 0.3555 - lr: 1.0000e-06
# Epoch 157/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5370 - iou_score: 0.4015 - val_loss: 0.5820 - val_iou_score: 0.3604 - lr: 1.0000e-06
# Epoch 158/500
# 400/400 [==============================] - 275s 686ms/step - loss: 0.5358 - iou_score: 0.4026 - val_loss: 0.5878 - val_iou_score: 0.3552 - lr: 1.0000e-06
# Epoch 159/500
# 400/400 [==============================] - 275s 689ms/step - loss: 0.5351 - iou_score: 0.4036 - val_loss: 0.5851 - val_iou_score: 0.3586 - lr: 1.0000e-06
# Epoch 160/500
# 400/400 [==============================] - 275s 686ms/step - loss: 0.5357 - iou_score: 0.4027 - val_loss: 0.5872 - val_iou_score: 0.3564 - lr: 1.0000e-06
# Epoch 161/500
# 400/400 [==============================] - 277s 691ms/step - loss: 0.5332 - iou_score: 0.4046 - val_loss: 0.5854 - val_iou_score: 0.3603 - lr: 1.0000e-06
# Epoch 162/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.5338 - iou_score: 0.4044 - val_loss: 0.5847 - val_iou_score: 0.3587 - lr: 1.0000e-06
# Epoch 163/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5320 - iou_score: 0.4067 - val_loss: 0.5863 - val_iou_score: 0.3579 - lr: 1.0000e-06
# Epoch 164/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5294 - iou_score: 0.4094 - val_loss: 0.5844 - val_iou_score: 0.3597 - lr: 1.0000e-06
# Epoch 165/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5326 - iou_score: 0.4046 - val_loss: 0.5834 - val_iou_score: 0.3614 - lr: 1.0000e-06
# Epoch 166/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.5312 - iou_score: 0.4069 - val_loss: 0.5828 - val_iou_score: 0.3616 - lr: 1.0000e-06
# Epoch 167/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5313 - iou_score: 0.4075 - val_loss: 0.5843 - val_iou_score: 0.3605 - lr: 1.0000e-06
# Epoch 168/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.5317 - iou_score: 0.4067 - val_loss: 0.5814 - val_iou_score: 0.3628 - lr: 1.0000e-06
# Epoch 169/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5296 - iou_score: 0.4086 - val_loss: 0.5851 - val_iou_score: 0.3599 - lr: 1.0000e-06
# Epoch 170/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5295 - iou_score: 0.4084 - val_loss: 0.5798 - val_iou_score: 0.3645 - lr: 1.0000e-06
# Epoch 171/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5288 - iou_score: 0.4089 - val_loss: 0.5825 - val_iou_score: 0.3619 - lr: 1.0000e-06
# Epoch 172/500
# 400/400 [==============================] - 275s 689ms/step - loss: 0.5271 - iou_score: 0.4111 - val_loss: 0.5833 - val_iou_score: 0.3614 - lr: 1.0000e-06
# Epoch 173/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.5233 - iou_score: 0.4163 - val_loss: 0.5842 - val_iou_score: 0.3608 - lr: 1.0000e-06
# Epoch 174/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5272 - iou_score: 0.4107 - val_loss: 0.5797 - val_iou_score: 0.3652 - lr: 1.0000e-06
# Epoch 175/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5258 - iou_score: 0.4130 - val_loss: 0.5845 - val_iou_score: 0.3597 - lr: 1.0000e-06
# Epoch 176/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5252 - iou_score: 0.4129 - val_loss: 0.5847 - val_iou_score: 0.3596 - lr: 1.0000e-06
# Epoch 177/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5233 - iou_score: 0.4153 - val_loss: 0.5812 - val_iou_score: 0.3630 - lr: 1.0000e-06
# Epoch 178/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.5236 - iou_score: 0.4146 - val_loss: 0.5843 - val_iou_score: 0.3595 - lr: 1.0000e-06
# Epoch 179/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5228 - iou_score: 0.4166 - val_loss: 0.5822 - val_iou_score: 0.3636 - lr: 1.0000e-06
# Epoch 180/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5233 - iou_score: 0.4148 - val_loss: 0.5843 - val_iou_score: 0.3589 - lr: 1.0000e-06
# Epoch 181/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5225 - iou_score: 0.4165 - val_loss: 0.5811 - val_iou_score: 0.3625 - lr: 1.0000e-06
# Epoch 182/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.5225 - iou_score: 0.4156 - val_loss: 0.5777 - val_iou_score: 0.3672 - lr: 1.0000e-06
# Epoch 183/500
# 400/400 [==============================] - 277s 691ms/step - loss: 0.5190 - iou_score: 0.4197 - val_loss: 0.5846 - val_iou_score: 0.3588 - lr: 1.0000e-06
# Epoch 184/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5191 - iou_score: 0.4192 - val_loss: 0.5832 - val_iou_score: 0.3597 - lr: 1.0000e-06
# Epoch 185/500
# 400/400 [==============================] - 277s 691ms/step - loss: 0.5185 - iou_score: 0.4208 - val_loss: 0.5811 - val_iou_score: 0.3627 - lr: 1.0000e-06
# Epoch 186/500
# 400/400 [==============================] - 279s 697ms/step - loss: 0.5178 - iou_score: 0.4212 - val_loss: 0.5752 - val_iou_score: 0.3691 - lr: 1.0000e-06
# Epoch 187/500
# 400/400 [==============================] - 277s 691ms/step - loss: 0.5175 - iou_score: 0.4214 - val_loss: 0.5807 - val_iou_score: 0.3625 - lr: 1.0000e-06
# Epoch 188/500
# 400/400 [==============================] - 278s 694ms/step - loss: 0.5187 - iou_score: 0.4210 - val_loss: 0.5811 - val_iou_score: 0.3652 - lr: 1.0000e-06
# Epoch 189/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5172 - iou_score: 0.4215 - val_loss: 0.5801 - val_iou_score: 0.3633 - lr: 1.0000e-06
# Epoch 190/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.5166 - iou_score: 0.4218 - val_loss: 0.5807 - val_iou_score: 0.3664 - lr: 1.0000e-06
# Epoch 191/500
# 400/400 [==============================] - 281s 703ms/step - loss: 0.5144 - iou_score: 0.4238 - val_loss: 0.5761 - val_iou_score: 0.3669 - lr: 1.0000e-06
# Epoch 192/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.5158 - iou_score: 0.4229 - val_loss: 0.5731 - val_iou_score: 0.3693 - lr: 1.0000e-06
# Epoch 193/500
# 400/400 [==============================] - 278s 694ms/step - loss: 0.5133 - iou_score: 0.4249 - val_loss: 0.5757 - val_iou_score: 0.3698 - lr: 1.0000e-06
# Epoch 194/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5142 - iou_score: 0.4244 - val_loss: 0.5777 - val_iou_score: 0.3648 - lr: 1.0000e-06
# Epoch 195/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5150 - iou_score: 0.4238 - val_loss: 0.5700 - val_iou_score: 0.3754 - lr: 1.0000e-06
# Epoch 196/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.5113 - iou_score: 0.4276 - val_loss: 0.5726 - val_iou_score: 0.3729 - lr: 1.0000e-06
# Epoch 197/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5124 - iou_score: 0.4266 - val_loss: 0.5732 - val_iou_score: 0.3717 - lr: 1.0000e-06
# Epoch 198/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.5103 - iou_score: 0.4292 - val_loss: 0.5750 - val_iou_score: 0.3706 - lr: 1.0000e-06
# Epoch 199/500
# 400/400 [==============================] - 269s 672ms/step - loss: 0.5114 - iou_score: 0.4273 - val_loss: 0.5793 - val_iou_score: 0.3654 - lr: 1.0000e-06
# Epoch 200/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.5134 - iou_score: 0.4255 - val_loss: 0.5732 - val_iou_score: 0.3725 - lr: 1.0000e-06
# Epoch 201/500
# 400/400 [==============================] - 279s 697ms/step - loss: 0.5091 - iou_score: 0.4305 - val_loss: 0.5763 - val_iou_score: 0.3675 - lr: 1.0000e-06
# Epoch 202/500
# 400/400 [==============================] - 278s 694ms/step - loss: 0.5102 - iou_score: 0.4291 - val_loss: 0.5752 - val_iou_score: 0.3682 - lr: 1.0000e-06
# Epoch 203/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.5095 - iou_score: 0.4293 - val_loss: 0.5677 - val_iou_score: 0.3777 - lr: 1.0000e-06
# Epoch 204/500
# 400/400 [==============================] - 277s 694ms/step - loss: 0.5074 - iou_score: 0.4320 - val_loss: 0.5747 - val_iou_score: 0.3687 - lr: 1.0000e-06
# Epoch 205/500
# 400/400 [==============================] - 279s 696ms/step - loss: 0.5060 - iou_score: 0.4338 - val_loss: 0.5787 - val_iou_score: 0.3655 - lr: 1.0000e-06
# Epoch 206/500
# 400/400 [==============================] - 279s 697ms/step - loss: 0.5086 - iou_score: 0.4298 - val_loss: 0.5770 - val_iou_score: 0.3657 - lr: 1.0000e-06
# Epoch 207/500
# 400/400 [==============================] - 326s 815ms/step - loss: 0.5072 - iou_score: 0.4321 - val_loss: 0.5743 - val_iou_score: 0.3707 - lr: 1.0000e-06
# Epoch 208/500
# 400/400 [==============================] - 279s 698ms/step - loss: 0.5081 - iou_score: 0.4309 - val_loss: 0.5735 - val_iou_score: 0.3702 - lr: 1.0000e-06
# Epoch 209/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5062 - iou_score: 0.4330 - val_loss: 0.5690 - val_iou_score: 0.3765 - lr: 1.0000e-06
# Epoch 210/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5047 - iou_score: 0.4352 - val_loss: 0.5686 - val_iou_score: 0.3769 - lr: 1.0000e-06
# Epoch 211/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5046 - iou_score: 0.4353 - val_loss: 0.5712 - val_iou_score: 0.3748 - lr: 1.0000e-06
# Epoch 212/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5043 - iou_score: 0.4350 - val_loss: 0.5707 - val_iou_score: 0.3753 - lr: 1.0000e-06
# Epoch 213/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.5004 - iou_score: 0.4398 - val_loss: 0.5730 - val_iou_score: 0.3717 - lr: 1.0000e-06
# Epoch 214/500
# 400/400 [==============================] - 275s 686ms/step - loss: 0.5074 - iou_score: 0.4310 - val_loss: 0.5690 - val_iou_score: 0.3764 - lr: 1.0000e-06
# Epoch 215/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5023 - iou_score: 0.4369 - val_loss: 0.5714 - val_iou_score: 0.3740 - lr: 1.0000e-06
# Epoch 216/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.4992 - iou_score: 0.4409 - val_loss: 0.5680 - val_iou_score: 0.3754 - lr: 1.0000e-06
# Epoch 217/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5021 - iou_score: 0.4373 - val_loss: 0.5727 - val_iou_score: 0.3715 - lr: 1.0000e-06
# Epoch 218/500
# 400/400 [==============================] - 275s 689ms/step - loss: 0.5007 - iou_score: 0.4388 - val_loss: 0.5730 - val_iou_score: 0.3708 - lr: 1.0000e-06
# Epoch 219/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.4990 - iou_score: 0.4407 - val_loss: 0.5706 - val_iou_score: 0.3745 - lr: 1.0000e-06
# Epoch 220/500
# 400/400 [==============================] - 278s 694ms/step - loss: 0.4991 - iou_score: 0.4415 - val_loss: 0.5738 - val_iou_score: 0.3710 - lr: 1.0000e-06
# Epoch 221/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.5016 - iou_score: 0.4374 - val_loss: 0.5707 - val_iou_score: 0.3745 - lr: 1.0000e-06
# Epoch 222/500
# 400/400 [==============================] - 279s 698ms/step - loss: 0.4960 - iou_score: 0.4442 - val_loss: 0.5743 - val_iou_score: 0.3707 - lr: 1.0000e-06
# Epoch 223/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.5025 - iou_score: 0.4367 - val_loss: 0.5724 - val_iou_score: 0.3726 - lr: 1.0000e-06
# Epoch 224/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.4993 - iou_score: 0.4401 - val_loss: 0.5703 - val_iou_score: 0.3757 - lr: 1.0000e-06
# Epoch 225/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.4989 - iou_score: 0.4410 - val_loss: 0.5740 - val_iou_score: 0.3704 - lr: 1.0000e-06
# Epoch 226/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.4973 - iou_score: 0.4430 - val_loss: 0.5708 - val_iou_score: 0.3744 - lr: 1.0000e-06
# Epoch 227/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.4972 - iou_score: 0.4437 - val_loss: 0.5749 - val_iou_score: 0.3705 - lr: 1.0000e-06
# Epoch 228/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.4991 - iou_score: 0.4405 - val_loss: 0.5669 - val_iou_score: 0.3779 - lr: 1.0000e-06
# Epoch 229/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.4982 - iou_score: 0.4414 - val_loss: 0.5675 - val_iou_score: 0.3777 - lr: 1.0000e-06
# Epoch 230/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.4964 - iou_score: 0.4442 - val_loss: 0.5716 - val_iou_score: 0.3735 - lr: 1.0000e-06
# Epoch 231/500
# 400/400 [==============================] - 278s 695ms/step - loss: 0.4940 - iou_score: 0.4465 - val_loss: 0.5643 - val_iou_score: 0.3822 - lr: 1.0000e-06
# Epoch 232/500
# 400/400 [==============================] - 278s 694ms/step - loss: 0.4950 - iou_score: 0.4451 - val_loss: 0.5672 - val_iou_score: 0.3791 - lr: 1.0000e-06
# Epoch 233/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.4942 - iou_score: 0.4459 - val_loss: 0.5725 - val_iou_score: 0.3723 - lr: 1.0000e-06
# Epoch 234/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.4946 - iou_score: 0.4459 - val_loss: 0.5665 - val_iou_score: 0.3798 - lr: 1.0000e-06
# Epoch 235/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.4948 - iou_score: 0.4448 - val_loss: 0.5640 - val_iou_score: 0.3816 - lr: 1.0000e-06
# Epoch 236/500
# 400/400 [==============================] - 277s 691ms/step - loss: 0.4935 - iou_score: 0.4465 - val_loss: 0.5664 - val_iou_score: 0.3793 - lr: 1.0000e-06
# Epoch 237/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.4916 - iou_score: 0.4493 - val_loss: 0.5757 - val_iou_score: 0.3686 - lr: 1.0000e-06
# Epoch 238/500
# 400/400 [==============================] - 278s 694ms/step - loss: 0.4895 - iou_score: 0.4517 - val_loss: 0.5677 - val_iou_score: 0.3763 - lr: 1.0000e-06
# Epoch 239/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.4905 - iou_score: 0.4504 - val_loss: 0.5661 - val_iou_score: 0.3792 - lr: 1.0000e-06
# Epoch 240/500
# 400/400 [==============================] - 278s 696ms/step - loss: 0.4910 - iou_score: 0.4491 - val_loss: 0.5705 - val_iou_score: 0.3767 - lr: 1.0000e-06
# Epoch 241/500
# 400/400 [==============================] - 278s 695ms/step - loss: 0.4898 - iou_score: 0.4511 - val_loss: 0.5635 - val_iou_score: 0.3817 - lr: 1.0000e-06
# Epoch 242/500
# 400/400 [==============================] - 276s 689ms/step - loss: 0.4920 - iou_score: 0.4479 - val_loss: 0.5733 - val_iou_score: 0.3718 - lr: 1.0000e-06
# Epoch 243/500
# 400/400 [==============================] - 281s 703ms/step - loss: 0.4863 - iou_score: 0.4558 - val_loss: 0.5677 - val_iou_score: 0.3785 - lr: 1.0000e-06
# Epoch 244/500
# 400/400 [==============================] - 299s 748ms/step - loss: 0.4892 - iou_score: 0.4512 - val_loss: 0.5642 - val_iou_score: 0.3825 - lr: 1.0000e-06
# Epoch 245/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.4892 - iou_score: 0.4525 - val_loss: 0.5654 - val_iou_score: 0.3804 - lr: 1.0000e-06
# Epoch 246/500
# 400/400 [==============================] - 283s 707ms/step - loss: 0.4877 - iou_score: 0.4542 - val_loss: 0.5696 - val_iou_score: 0.3741 - lr: 1.0000e-06
# Epoch 247/500
# 400/400 [==============================] - 279s 699ms/step - loss: 0.4888 - iou_score: 0.4519 - val_loss: 0.5643 - val_iou_score: 0.3818 - lr: 1.0000e-06
# Epoch 248/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.4884 - iou_score: 0.4524 - val_loss: 0.5699 - val_iou_score: 0.3765 - lr: 1.0000e-06
# Epoch 249/500
# 400/400 [==============================] - 279s 698ms/step - loss: 0.4867 - iou_score: 0.4549 - val_loss: 0.5643 - val_iou_score: 0.3823 - lr: 1.0000e-06
# Epoch 250/500
# 400/400 [==============================] - 285s 713ms/step - loss: 0.4878 - iou_score: 0.4535 - val_loss: 0.5704 - val_iou_score: 0.3751 - lr: 1.0000e-06
# Epoch 251/500
# 400/400 [==============================] - 285s 713ms/step - loss: 0.4836 - iou_score: 0.4575 - val_loss: 0.5671 - val_iou_score: 0.3780 - lr: 1.0000e-06
# Epoch 252/500
# 400/400 [==============================] - 290s 724ms/step - loss: 0.4857 - iou_score: 0.4558 - val_loss: 0.5627 - val_iou_score: 0.3836 - lr: 1.0000e-06
# Epoch 253/500
# 400/400 [==============================] - 287s 717ms/step - loss: 0.4851 - iou_score: 0.4562 - val_loss: 0.5665 - val_iou_score: 0.3772 - lr: 1.0000e-06
# Epoch 254/500
# 400/400 [==============================] - 284s 710ms/step - loss: 0.4820 - iou_score: 0.4607 - val_loss: 0.5654 - val_iou_score: 0.3800 - lr: 1.0000e-06
# Epoch 255/500
# 400/400 [==============================] - 286s 714ms/step - loss: 0.4820 - iou_score: 0.4599 - val_loss: 0.5693 - val_iou_score: 0.3749 - lr: 1.0000e-06
# Epoch 256/500
# 400/400 [==============================] - 288s 720ms/step - loss: 0.4853 - iou_score: 0.4573 - val_loss: 0.5719 - val_iou_score: 0.3743 - lr: 1.0000e-06
# Epoch 257/500
# 400/400 [==============================] - 284s 711ms/step - loss: 0.4805 - iou_score: 0.4615 - val_loss: 0.5549 - val_iou_score: 0.3918 - lr: 1.0000e-06
# Epoch 258/500
# 400/400 [==============================] - 278s 695ms/step - loss: 0.4846 - iou_score: 0.4565 - val_loss: 0.5648 - val_iou_score: 0.3820 - lr: 1.0000e-06
# Epoch 259/500
# 400/400 [==============================] - 279s 696ms/step - loss: 0.4863 - iou_score: 0.4546 - val_loss: 0.5587 - val_iou_score: 0.3878 - lr: 1.0000e-06
# Epoch 260/500
# 400/400 [==============================] - 277s 692ms/step - loss: 0.4833 - iou_score: 0.4594 - val_loss: 0.5637 - val_iou_score: 0.3830 - lr: 1.0000e-06
# Epoch 261/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.4828 - iou_score: 0.4590 - val_loss: 0.5677 - val_iou_score: 0.3799 - lr: 1.0000e-06
# Epoch 262/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.4806 - iou_score: 0.4619 - val_loss: 0.5650 - val_iou_score: 0.3803 - lr: 1.0000e-06
# Epoch 263/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.4825 - iou_score: 0.4589 - val_loss: 0.5656 - val_iou_score: 0.3801 - lr: 1.0000e-06
# Epoch 264/500
# 400/400 [==============================] - 276s 690ms/step - loss: 0.4823 - iou_score: 0.4580 - val_loss: 0.5660 - val_iou_score: 0.3791 - lr: 1.0000e-06
# Epoch 265/500
# 400/400 [==============================] - 282s 706ms/step - loss: 0.4791 - iou_score: 0.4636 - val_loss: 0.5630 - val_iou_score: 0.3849 - lr: 1.0000e-06
# Epoch 266/500
# 400/400 [==============================] - 275s 686ms/step - loss: 0.4802 - iou_score: 0.4614 - val_loss: 0.5628 - val_iou_score: 0.3820 - lr: 1.0000e-06
# Epoch 267/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.4782 - iou_score: 0.4641 - val_loss: 0.5589 - val_iou_score: 0.3887 - lr: 1.0000e-06
# Epoch 268/500
# 400/400 [==============================] - 277s 693ms/step - loss: 0.4769 - iou_score: 0.4668 - val_loss: 0.5621 - val_iou_score: 0.3840 - lr: 1.0000e-06
# Epoch 269/500
# 400/400 [==============================] - 310s 774ms/step - loss: 0.4764 - iou_score: 0.4660 - val_loss: 0.5655 - val_iou_score: 0.3814 - lr: 1.0000e-06
# Epoch 270/500
# 400/400 [==============================] - 278s 694ms/step - loss: 0.4808 - iou_score: 0.4615 - val_loss: 0.5641 - val_iou_score: 0.3827 - lr: 1.0000e-06
# Epoch 271/500
# 400/400 [==============================] - 280s 700ms/step - loss: 0.4782 - iou_score: 0.4641 - val_loss: 0.5637 - val_iou_score: 0.3823 - lr: 1.0000e-06
# Epoch 272/500
# 400/400 [==============================] - 280s 699ms/step - loss: 0.4787 - iou_score: 0.4635 - val_loss: 0.5644 - val_iou_score: 0.3841 - lr: 1.0000e-06
# Epoch 273/500
# 400/400 [==============================] - 280s 700ms/step - loss: 0.4765 - iou_score: 0.4659 - val_loss: 0.5589 - val_iou_score: 0.3883 - lr: 1.0000e-06
# Epoch 274/500
# 400/400 [==============================] - 279s 698ms/step - loss: 0.4748 - iou_score: 0.4692 - val_loss: 0.5593 - val_iou_score: 0.3868 - lr: 1.0000e-06
# Epoch 275/500
# 400/400 [==============================] - 288s 719ms/step - loss: 0.4737 - iou_score: 0.4693 - val_loss: 0.5649 - val_iou_score: 0.3822 - lr: 1.0000e-06
# Epoch 276/500
# 400/400 [==============================] - 293s 732ms/step - loss: 0.4740 - iou_score: 0.4689 - val_loss: 0.5625 - val_iou_score: 0.3832 - lr: 1.0000e-06
# Epoch 277/500
# 400/400 [==============================] - 322s 805ms/step - loss: 0.4748 - iou_score: 0.4681 - val_loss: 0.5610 - val_iou_score: 0.3854 - lr: 1.0000e-06
# Epoch 278/500
# 400/400 [==============================] - 299s 748ms/step - loss: 0.4775 - iou_score: 0.4651 - val_loss: 0.5620 - val_iou_score: 0.3869 - lr: 1.0000e-06
# Epoch 279/500
# 400/400 [==============================] - 292s 730ms/step - loss: 0.4751 - iou_score: 0.4671 - val_loss: 0.5613 - val_iou_score: 0.3845 - lr: 1.0000e-06
# Epoch 280/500
# 400/400 [==============================] - 289s 722ms/step - loss: 0.4757 - iou_score: 0.4673 - val_loss: 0.5569 - val_iou_score: 0.3894 - lr: 1.0000e-06
# Epoch 281/500
# 400/400 [==============================] - 298s 744ms/step - loss: 0.4736 - iou_score: 0.4687 - val_loss: 0.5621 - val_iou_score: 0.3846 - lr: 1.0000e-06
# Epoch 282/500
# 400/400 [==============================] - 279s 698ms/step - loss: 0.4736 - iou_score: 0.4687 - val_loss: 0.5591 - val_iou_score: 0.3877 - lr: 1.0000e-06
# Epoch 283/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.4705 - iou_score: 0.4744 - val_loss: 0.5665 - val_iou_score: 0.3790 - lr: 1.0000e-06
# Epoch 284/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.4707 - iou_score: 0.4732 - val_loss: 0.5616 - val_iou_score: 0.3853 - lr: 1.0000e-06
# Epoch 285/500
# ...
# Epoch 406/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.4192 - iou_score: 0.5329 - val_loss: 0.5466 - val_iou_score: 0.4057 - lr: 1.0000e-06
# Epoch 407/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.4167 - iou_score: 0.5395 - val_loss: 0.5484 - val_iou_score: 0.4017 - lr: 1.0000e-06
# Epoch 408/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4189 - iou_score: 0.5348 - val_loss: 0.5485 - val_iou_score: 0.4000 - lr: 1.0000e-06
# Epoch 409/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.4168 - iou_score: 0.5355 - val_loss: 0.5503 - val_iou_score: 0.3996 - lr: 1.0000e-06
# Epoch 410/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4180 - iou_score: 0.5357 - val_loss: 0.5492 - val_iou_score: 0.4028 - lr: 1.0000e-06
# Epoch 411/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4176 - iou_score: 0.5362 - val_loss: 0.5435 - val_iou_score: 0.4073 - lr: 1.0000e-06
# Epoch 412/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4190 - iou_score: 0.5345 - val_loss: 0.5460 - val_iou_score: 0.4045 - lr: 1.0000e-06
# Epoch 413/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4148 - iou_score: 0.5413 - val_loss: 0.5479 - val_iou_score: 0.4004 - lr: 1.0000e-06
# Epoch 414/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4197 - iou_score: 0.5338 - val_loss: 0.5489 - val_iou_score: 0.4013 - lr: 1.0000e-06
# Epoch 415/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.4177 - iou_score: 0.5343 - val_loss: 0.5446 - val_iou_score: 0.4067 - lr: 1.0000e-06
# Epoch 416/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4190 - iou_score: 0.5381 - val_loss: 0.5502 - val_iou_score: 0.3985 - lr: 1.0000e-06
# Epoch 417/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.4158 - iou_score: 0.5266 - val_loss: 0.5489 - val_iou_score: 0.4012 - lr: 1.0000e-06
# Epoch 418/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.4139 - iou_score: 0.5367 - val_loss: 0.5442 - val_iou_score: 0.4070 - lr: 1.0000e-06
# Epoch 419/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.4185 - iou_score: 0.5306 - val_loss: 0.5460 - val_iou_score: 0.4049 - lr: 1.0000e-06
# Epoch 420/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4135 - iou_score: 0.5418 - val_loss: 0.5437 - val_iou_score: 0.4077 - lr: 1.0000e-06
# Epoch 421/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.4130 - iou_score: 0.5600 - val_loss: 0.5417 - val_iou_score: 0.4100 - lr: 1.0000e-06
# Epoch 422/500
# 400/400 [==============================] - 274s 686ms/step - loss: 0.4095 - iou_score: 0.5459 - val_loss: 0.5438 - val_iou_score: 0.4052 - lr: 1.0000e-06
# Epoch 423/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4111 - iou_score: 0.5405 - val_loss: 0.5486 - val_iou_score: 0.3998 - lr: 1.0000e-06
# Epoch 424/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4128 - iou_score: 0.5318 - val_loss: 0.5384 - val_iou_score: 0.4139 - lr: 1.0000e-06
# Epoch 425/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4133 - iou_score: 0.5375 - val_loss: 0.5414 - val_iou_score: 0.4143 - lr: 1.0000e-06
# Epoch 426/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4149 - iou_score: 0.5404 - val_loss: 0.5451 - val_iou_score: 0.4063 - lr: 1.0000e-06
# Epoch 427/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.4113 - iou_score: 0.5424 - val_loss: 0.5463 - val_iou_score: 0.4069 - lr: 1.0000e-06
# Epoch 428/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4098 - iou_score: 0.5449 - val_loss: 0.5436 - val_iou_score: 0.4080 - lr: 1.0000e-06
# Epoch 429/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.4109 - iou_score: 0.5424 - val_loss: 0.5401 - val_iou_score: 0.4133 - lr: 1.0000e-06
# Epoch 430/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.4100 - iou_score: 0.5446 - val_loss: 0.5412 - val_iou_score: 0.4079 - lr: 1.0000e-06
# Epoch 431/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4141 - iou_score: 0.5372 - val_loss: 0.5497 - val_iou_score: 0.4008 - lr: 1.0000e-06
# Epoch 432/500
# 400/400 [==============================] - 271s 679ms/step - loss: 0.4126 - iou_score: 0.5391 - val_loss: 0.5435 - val_iou_score: 0.4054 - lr: 1.0000e-06
# Epoch 433/500
# 400/400 [==============================] - 273s 684ms/step - loss: 0.4074 - iou_score: 0.5242 - val_loss: 0.5425 - val_iou_score: 0.4064 - lr: 1.0000e-06
# Epoch 434/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.4130 - iou_score: 0.5416 - val_loss: 0.5456 - val_iou_score: 0.4095 - lr: 1.0000e-06
# Epoch 435/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4107 - iou_score: 0.5427 - val_loss: 0.5408 - val_iou_score: 0.4113 - lr: 1.0000e-06
# Epoch 436/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.4073 - iou_score: 0.5490 - val_loss: 0.5408 - val_iou_score: 0.4127 - lr: 1.0000e-06
# Epoch 437/500
# 400/400 [==============================] - 276s 691ms/step - loss: 0.4031 - iou_score: 0.5546 - val_loss: 0.5397 - val_iou_score: 0.4103 - lr: 1.0000e-06
# Epoch 438/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.4059 - iou_score: 0.5570 - val_loss: 0.5411 - val_iou_score: 0.4069 - lr: 1.0000e-06
# Epoch 439/500
# 400/400 [==============================] - 272s 679ms/step - loss: 0.4096 - iou_score: 0.5397 - val_loss: 0.5416 - val_iou_score: 0.4090 - lr: 1.0000e-06
# Epoch 440/500
# 400/400 [==============================] - 270s 675ms/step - loss: 0.4112 - iou_score: 0.5428 - val_loss: 0.5424 - val_iou_score: 0.4094 - lr: 1.0000e-06
# Epoch 441/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.4087 - iou_score: 0.5383 - val_loss: 0.5468 - val_iou_score: 0.4026 - lr: 1.0000e-06
# Epoch 442/500
# 400/400 [==============================] - 273s 681ms/step - loss: 0.4060 - iou_score: 0.5539 - val_loss: 0.5402 - val_iou_score: 0.4106 - lr: 1.0000e-06
# Epoch 443/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4038 - iou_score: 0.5446 - val_loss: 0.5418 - val_iou_score: 0.4091 - lr: 1.0000e-06
# Epoch 444/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.4074 - iou_score: 0.5478 - val_loss: 0.5426 - val_iou_score: 0.4076 - lr: 1.0000e-06
# Epoch 445/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4062 - iou_score: 0.5546 - val_loss: 0.5408 - val_iou_score: 0.4096 - lr: 1.0000e-06
# Epoch 446/500
# 400/400 [==============================] - 272s 679ms/step - loss: 0.4039 - iou_score: 0.5499 - val_loss: 0.5395 - val_iou_score: 0.4102 - lr: 1.0000e-06
# Epoch 447/500
# 400/400 [==============================] - 272s 679ms/step - loss: 0.4050 - iou_score: 0.5480 - val_loss: 0.5374 - val_iou_score: 0.4128 - lr: 1.0000e-06
# Epoch 448/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4053 - iou_score: 0.5493 - val_loss: 0.5435 - val_iou_score: 0.4101 - lr: 1.0000e-06
# Epoch 449/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.4086 - iou_score: 0.5458 - val_loss: 0.5379 - val_iou_score: 0.4148 - lr: 1.0000e-06
# Epoch 450/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4067 - iou_score: 0.5446 - val_loss: 0.5431 - val_iou_score: 0.4070 - lr: 1.0000e-06
# Epoch 451/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4013 - iou_score: 0.5539 - val_loss: 0.5392 - val_iou_score: 0.4129 - lr: 1.0000e-06
# Epoch 452/500
# 400/400 [==============================] - 271s 676ms/step - loss: 0.4038 - iou_score: 0.5523 - val_loss: 0.5476 - val_iou_score: 0.4037 - lr: 1.0000e-06
# Epoch 453/500
# 400/400 [==============================] - 275s 688ms/step - loss: 0.4009 - iou_score: 0.5546 - val_loss: 0.5465 - val_iou_score: 0.4054 - lr: 1.0000e-06
# Epoch 454/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.4055 - iou_score: 0.5474 - val_loss: 0.5426 - val_iou_score: 0.4068 - lr: 1.0000e-06
# Epoch 455/500
# 400/400 [==============================] - 272s 679ms/step - loss: 0.4044 - iou_score: 0.5513 - val_loss: 0.5388 - val_iou_score: 0.4114 - lr: 1.0000e-06
# Epoch 456/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3996 - iou_score: 0.5540 - val_loss: 0.5395 - val_iou_score: 0.4115 - lr: 1.0000e-06
# Epoch 457/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.3990 - iou_score: 0.5605 - val_loss: 0.5375 - val_iou_score: 0.4132 - lr: 1.0000e-06
# Epoch 458/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4027 - iou_score: 0.5573 - val_loss: 0.5424 - val_iou_score: 0.4099 - lr: 1.0000e-06
# Epoch 459/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.4021 - iou_score: 0.5552 - val_loss: 0.5423 - val_iou_score: 0.4072 - lr: 1.0000e-06
# Epoch 460/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.3995 - iou_score: 0.5515 - val_loss: 0.5380 - val_iou_score: 0.4121 - lr: 1.0000e-06
# Epoch 461/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3992 - iou_score: 0.5563 - val_loss: 0.5384 - val_iou_score: 0.4125 - lr: 1.0000e-06
# Epoch 462/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4021 - iou_score: 0.5561 - val_loss: 0.5375 - val_iou_score: 0.4153 - lr: 1.0000e-06
# Epoch 463/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.4013 - iou_score: 0.5560 - val_loss: 0.5417 - val_iou_score: 0.4092 - lr: 1.0000e-06
# Epoch 464/500
# 400/400 [==============================] - 271s 679ms/step - loss: 0.3987 - iou_score: 0.5694 - val_loss: 0.5393 - val_iou_score: 0.4121 - lr: 1.0000e-06
# Epoch 465/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.3980 - iou_score: 0.5617 - val_loss: 0.5412 - val_iou_score: 0.4079 - lr: 1.0000e-06
# Epoch 466/500
# 400/400 [==============================] - 275s 687ms/step - loss: 0.3957 - iou_score: 0.5661 - val_loss: 0.5374 - val_iou_score: 0.4146 - lr: 1.0000e-06
# Epoch 467/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.3954 - iou_score: 0.5670 - val_loss: 0.5392 - val_iou_score: 0.4127 - lr: 1.0000e-06
# Epoch 468/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3968 - iou_score: 0.5611 - val_loss: 0.5395 - val_iou_score: 0.4138 - lr: 1.0000e-06
# Epoch 469/500
# 400/400 [==============================] - 274s 684ms/step - loss: 0.3953 - iou_score: 0.5629 - val_loss: 0.5368 - val_iou_score: 0.4187 - lr: 1.0000e-06
# Epoch 470/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.3990 - iou_score: 0.5641 - val_loss: 0.5342 - val_iou_score: 0.4192 - lr: 1.0000e-06
# Epoch 471/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.3954 - iou_score: 0.5607 - val_loss: 0.5401 - val_iou_score: 0.4114 - lr: 1.0000e-06
# Epoch 472/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3960 - iou_score: 0.5633 - val_loss: 0.5320 - val_iou_score: 0.4262 - lr: 1.0000e-06
# Epoch 473/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.3956 - iou_score: 0.5617 - val_loss: 0.5396 - val_iou_score: 0.4105 - lr: 1.0000e-06
# Epoch 474/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.3973 - iou_score: 0.5571 - val_loss: 0.5414 - val_iou_score: 0.4075 - lr: 1.0000e-06
# Epoch 475/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.3964 - iou_score: 0.5586 - val_loss: 0.5390 - val_iou_score: 0.4113 - lr: 1.0000e-06
# Epoch 476/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.3966 - iou_score: 0.5618 - val_loss: 0.5327 - val_iou_score: 0.4211 - lr: 1.0000e-06
# Epoch 477/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3956 - iou_score: 0.5591 - val_loss: 0.5365 - val_iou_score: 0.4136 - lr: 1.0000e-06
# Epoch 478/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.3930 - iou_score: 0.5745 - val_loss: 0.5426 - val_iou_score: 0.4069 - lr: 1.0000e-06
# Epoch 479/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.3949 - iou_score: 0.5642 - val_loss: 0.5381 - val_iou_score: 0.4142 - lr: 1.0000e-06
# Epoch 480/500
# 400/400 [==============================] - 274s 685ms/step - loss: 0.3921 - iou_score: 0.5647 - val_loss: 0.5330 - val_iou_score: 0.4195 - lr: 1.0000e-06
# Epoch 481/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3902 - iou_score: 0.5682 - val_loss: 0.5395 - val_iou_score: 0.4118 - lr: 1.0000e-06
# Epoch 482/500
# 400/400 [==============================] - 273s 682ms/step - loss: 0.3915 - iou_score: 0.5671 - val_loss: 0.5340 - val_iou_score: 0.4185 - lr: 1.0000e-06
# Epoch 483/500
# 400/400 [==============================] - 273s 681ms/step - loss: 0.3911 - iou_score: 0.5681 - val_loss: 0.5350 - val_iou_score: 0.4147 - lr: 1.0000e-06
# Epoch 484/500
# 400/400 [==============================] - 272s 679ms/step - loss: 0.3911 - iou_score: 0.5680 - val_loss: 0.5417 - val_iou_score: 0.4135 - lr: 1.0000e-06
# Epoch 485/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3935 - iou_score: 0.5635 - val_loss: 0.5344 - val_iou_score: 0.4204 - lr: 1.0000e-06
# Epoch 486/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.3943 - iou_score: 0.5617 - val_loss: 0.5341 - val_iou_score: 0.4180 - lr: 1.0000e-06
# Epoch 487/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.3938 - iou_score: 0.5662 - val_loss: 0.5393 - val_iou_score: 0.4125 - lr: 1.0000e-06
# Epoch 488/500
# 400/400 [==============================] - 273s 684ms/step - loss: 0.3913 - iou_score: 0.5675 - val_loss: 0.5365 - val_iou_score: 0.4149 - lr: 1.0000e-06
# Epoch 489/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3897 - iou_score: 0.5990 - val_loss: 0.5343 - val_iou_score: 0.4194 - lr: 1.0000e-06
# Epoch 490/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3914 - iou_score: 0.5633 - val_loss: 0.5376 - val_iou_score: 0.4133 - lr: 1.0000e-06
# Epoch 491/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.3913 - iou_score: 0.5618 - val_loss: 0.5429 - val_iou_score: 0.4082 - lr: 1.0000e-06
# Epoch 492/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.3904 - iou_score: 0.5441 - val_loss: 0.5371 - val_iou_score: 0.4144 - lr: 1.0000e-06
# Epoch 493/500
# 400/400 [==============================] - 272s 680ms/step - loss: 0.3881 - iou_score: 0.5755 - val_loss: 0.5383 - val_iou_score: 0.4114 - lr: 1.0000e-06
# Epoch 494/500
# 400/400 [==============================] - 271s 679ms/step - loss: 0.3926 - iou_score: 11.6737 - val_loss: 0.5379 - val_iou_score: 0.4117 - lr: 1.0000e-06
# Epoch 495/500
# 400/400 [==============================] - 272s 681ms/step - loss: 0.3892 - iou_score: 0.5671 - val_loss: 0.5412 - val_iou_score: 0.4126 - lr: 1.0000e-06
# Epoch 496/500
# 400/400 [==============================] - 272s 679ms/step - loss: 0.3934 - iou_score: 0.5649 - val_loss: 0.5359 - val_iou_score: 0.4148 - lr: 1.0000e-06
# Epoch 497/500
# 400/400 [==============================] - 271s 678ms/step - loss: 0.3928 - iou_score: 0.5620 - val_loss: 0.5346 - val_iou_score: 0.4176 - lr: 1.0000e-06
# Epoch 498/500
# 400/400 [==============================] - 273s 683ms/step - loss: 0.3855 - iou_score: 0.5666 - val_loss: 0.5390 - val_iou_score: 0.4151 - lr: 1.0000e-06
# Epoch 499/500
# 400/400 [==============================] - 271s 677ms/step - loss: 0.3893 - iou_score: 0.7251 - val_loss: 0.5391 - val_iou_score: 0.4121 - lr: 1.0000e-06
# Epoch 500/500
# 400/400 [==============================] - 270s 676ms/step - loss: 0.3935 - iou_score: 0.5632 - val_loss: 0.5359 - val_iou_score: 0.4151 - lr: 1.0000e-06

# %%
for i,x in enumerate(history.history['iou_score']):
    if x > 5:
        history.history['iou_score'].pop(i)

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
images_ = test_df['image'].values
masks_ = test_df['mask'].values
lst = np.arange(len(images_))

# %%
import random
ids = np.random.choice(lst, size = 15, replace = False)
for i in ids:
  image = cv2.imread(images_[i], cv2.IMREAD_UNCHANGED)
  image = cv2.resize(image, (256, 256),  interpolation = cv2.INTER_AREA)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = np.expand_dims(image, axis=0)

  mask  = cv2.imread(masks_[i], cv2.IMREAD_UNCHANGED)
  mask = cv2.resize(mask, (256, 256),  interpolation = cv2.INTER_AREA)
  mask = mask / 10
  pred = model.predict(image,verbose=1)
  pred = tf.argmax(pred, axis=-1)

  fig = plt.figure(figsize=(10,6))
  #plt.figure(figsize=(10,6))
  ax1 = fig.add_subplot(131)
  ax1.imshow(image[0,:,:])
  ax2=fig.add_subplot(132)
  ax2.imshow(mask)
  ax3=fig.add_subplot(133)
  ax3.imshow(pred[0,:,:])
  ax1.title.set_text('Image')
  ax2.title.set_text('Original Mask')
  ax3.title.set_text('Predicted Mask')
  plt.show()
# Out:
# 1/1 [==============================] - 0s 256us/step
# 1/1 [==============================] - 0s 998us/step
# 1/1 [==============================] - 0s 850us/step
# 1/1 [==============================] - 0s 998us/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 965us/step
# 1/1 [==============================] - 0s 998us/step
# 1/1 [==============================] - 0s 602us/step
# 1/1 [==============================] - 0s 998us/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 998us/step
# 1/1 [==============================] - 0s 999us/step

# %%
tf.keras.utils.plot_model(
    model, to_file='model_unet.png', show_shapes=True, show_layer_names=True,
    rankdir='TB')
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %% [markdown]
# # Task 3: Training CANet

# %%
import tensorflow as tf
# tf.compat.v1.enable_eager_execution()
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Multiply
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

# %% [markdown]
# * as a part of this assignment we will be implementing the architecture based on this paper https://arxiv.org/pdf/2002.12041.pdf
# * We will be using the custom layers concept that we used in seq-seq assignment
# * You can devide the whole architecture can be devided into two parts
#     1. Encoder
#     2. Decoder
#     <img src='https://i.imgur.com/prH3Mno.png' width="600">
# * Encoder:
#     * The first step of the encoder is to create the channel maps [$C_1$, $C_2$, $C_3$, $C_4$]
#     * $C_1$ width and heigths are 4x times less than the original image
#     * $C_2$ width and heigths are 8x times less than the original image
#     * $C_3$ width and heigths are 8x times less than the original image
#     * $C_4$ width and heigths are 8x times less than the original image
#     * <i>you can reduce the dimensions by using stride parameter</i>.
#     * [$C_1$, $C_2$, $C_3$, $C_4$] are formed by applying a "conv block" followed by $k$ number of "identity block". i.e the $C_k$ feature map will single "conv block" followed by $k$ number of "identity blocks".
#     <table>
#     <tr><td><img src="https://i.imgur.com/R8Gdypo.png" width="300"></td>
#         <td><img src="https://i.imgur.com/KNunjQK.png" width="250"></td></tr>
#     </table>
#     * <strong>The conv block and identity block of $C_1$</strong>: the number filters in the covolutional layers will be $[4,4,8]$ and the number of filters in the parallel conv layer will also be $8$.
#     * <strong>The conv block and identity block of $C_2$</strong>: the number filters in the covolutional layers will be $[8,8,16]$ and the number of filters in the parallel conv layer will also be $16$.
#     * <strong>The conv block and identity block of $C_3$</strong>: the number filters in the covolutional layers will be $[16,16,32]$ and the number of filters in the parallel conv layer will also be $32$.
#     * <strong>The conv block and identity block of $C_4$</strong>: the number filters in the covolutional layers will be $[32,32,64]$ and the number of filters in the parallel conv layer will also be $64$.
#     * Here $\oplus$ represents the elementwise sum
#     <br>
#
#     <font color="red">NOTE: these filters are of your choice, you can explore more options also</font>
#
#     * Example: if your image is of size $(512, 512, 3)$
#         * the output after $C_1$ will be $128*128*8$
#         * the output after $C_2$ will be $64*64*16$
#         * the output after $C_3$ will be $64*64*32$
#         * the output after $C_4$ will be $64*64*64$

# %%
class convolutional_block(tf.keras.layers.Layer):
    def __init__(self, kernel=3,  filters=[4,4,8], stride=1, name="conv_block"):
        super().__init__(name=name)
        self.F1, self.F2, self.F3 = filters
        self.kernel = kernel
        self.stride = stride
        self.conv_1 = Conv2D(self.F1, (1,1),strides = (1,1),kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn1 = BatchNormalization()
        self.conv_act1 = Activation('relu')
        
        self.conv_2 = Conv2D(self.F2, (self.kernel,self.kernel),strides = (self.stride,self.stride),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn2 = BatchNormalization()
        self.conv_act2 = Activation('relu')
        
        self.conv_3 = Conv2D(self.F3, (1,1),strides = (1,1),kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn3 = BatchNormalization()
        self.conv_act3 = Activation('relu')
        
        self.conv_co_parallel = Conv2D(self.F3, (self.kernel,self.kernel),strides = (self.stride,self.stride),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn_parallel = BatchNormalization()
        self.conv_act_parallel = Activation('relu')
        
        self.conv_add = Add()
        self.conv_act_final = Activation('relu')
        
    def call(self, X):
        # write the architecutre that was mentioned above
        parallel = self.conv_1(X)
        parallel = self.conv_bn1(parallel)
        parallel = self.conv_act1(parallel)
        
        parallel = self.conv_2(parallel)
        parallel = self.conv_bn2(parallel)
        parallel = self.conv_act2(parallel)
        
        parallel = self.conv_3(parallel)
        parallel = self.conv_bn3(parallel)
        parallel = self.conv_act3(parallel)
        
        co_parallel = self.conv_co_parallel(X)
        co_parallel = self.conv_bn_parallel(co_parallel)
        co_parallel = self.conv_act_parallel(co_parallel)
        
        y = self.conv_add([parallel, co_parallel])
        X = self.conv_act_final(y)
        
        return X

# %%
class identity_block(tf.keras.layers.Layer):
    def __init__(self, kernel=3,  filters=[4,4,8], name="identity_block"):
        super().__init__(name=name)
        self.F1, self.F2, self.F3 = filters
        self.kernel = kernel
        self.conv_1 = Conv2D(self.F1, (1,1),strides = (1,1),kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn1 = BatchNormalization()
        self.conv_act1 = Activation('relu')
        
        self.conv_2 = Conv2D(self.F2, (self.kernel,self.kernel),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn2 = BatchNormalization()
        self.conv_act2 = Activation('relu')
        
        self.conv_3 = Conv2D(self.F3, (1,1),strides = (1,1),kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn3 = BatchNormalization()
        self.conv_act3 = Activation('relu')
        
        self.conv_add = Add()
        self.conv_act_final = Activation('relu')
        
    def call(self, X):
        # write the architecutre that was mentioned above
        parallel = self.conv_1(X)
        parallel = self.conv_bn1(parallel)
        parallel = self.conv_act1(parallel)
        
        parallel = self.conv_2(parallel)
        parallel = self.conv_bn2(parallel)
        parallel = self.conv_act2(parallel)
        
        parallel = self.conv_3(parallel)
        parallel = self.conv_bn3(parallel)
        parallel = self.conv_act3(parallel)
        
        y = self.conv_add([parallel, X])
        X = self.conv_act_final(y)
        
        return X

# %% [markdown]
# * The output of the $C_4$ will be passed to $\text{Chained Context Aggregation Module (CAM)}$
# <img src='https://i.imgur.com/Bu63AAA.png' width="400">
# * The CAM module will have two operations names Context flow and Global flow
# * <strong>The Global flow</strong>:
#     * as shown in the above figure first we willl apply  <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D">global avg pooling</a> which results in (#, 1, 1, number_of_filters) then applying <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization?version=nightly">BN</a>, <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU">RELU</a>, $1*1 \text{ Conv}$ layer sequentially which results a matrix (#, 1, 1, number_of_filters). Finally apply <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D">upsampling</a> / <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose">conv2d transpose</a> to make the output same as the input dimensions (#, input_height, input_width, number_of_filters)
#     * If you use <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D">upsampling</a> then use bilinear pooling as interpolation technique
# * <strong>The Context flow</strong>:
#     * as shown in the above figure (c) the context flow will get inputs from two modules `a. C4` `b. From the above flow`
#     * We will be <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/Concatenate">concatinating</a> the both inputs on the last axis.
#     * After the concatination we will be applying <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/AveragePooling2D"> Average pooling </a> which reduces the size of feature map by $N\times$ times
#     * In the paper it was mentioned that to apply a group convolutions, but for the assignment we will be applying the simple conv layers with kernel size $(3*3)$
#     * We are skipping the channel shuffling
#     * similarly we will be applying a simple conv layers with kernel size $(3*3)$ consider this output is X
#     * later we will get the Y=(X $\otimes \sigma((1\times1)conv(relu((1\times1)conv(X))))) \oplus X$, here $\oplus$ is elementwise addition and $\otimes$ is elementwise multiplication
#     * Finally apply <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D">upsampling</a> / <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose">conv2d transpose</a> to make the output same as the input dimensions (#, input_height, input_width, number_of_filters)
#     * If you use <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D">upsampling</a> then use bilinear pooling as interpolation technique
#
# NOTE: here N times reduction and N time increments makes the input and out shape same, you can explore with the N values, you can choose N = 2 or 4
#
# * Example with N=2:
#     * Assume the C4 is of shape (64,64,64) then the shape of GF will be (64,64,32)
#     * Assume the C4 is of shape (64,64,64) and the shape of GF is (64,64,32) then the shape of CF1 will be (64,64,32)
#     * Assume the C4 is of shape (64,64,64) and the shape of CF1 is (64,64,32) then the shape of CF2 will be (64,64,32)
#     * Assume the C4 is of shape (64,64,64) and the shape of CF2 is (64,64,32) then the shape of CF3 will be (64,64,32)

# %%
class global_flow(tf.keras.layers.Layer):
    def __init__(self, name="global_flow"):
        super().__init__(name=name)
        self.conv_globalflow_pool = GlobalAveragePooling2D()
        self.conv_globalflow_reshape = Reshape((1,1,128))
        self.conv_globalflow_bn = BatchNormalization(axis=1)
        self.conv_globalflow_act = Activation('relu')
        self.conv_1_globalflow = Conv2D(64, (1,1),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_UpSampling = Conv2DTranspose(64,(3,3),strides=64,padding="same")
    def call(self, X):
        # implement the global flow operatiom
        serial = self.conv_globalflow_pool(X)
        serial = self.conv_globalflow_reshape(serial)
        serial = self.conv_globalflow_bn(serial)
        serial = self.conv_globalflow_act(serial)
        serial = self.conv_1_globalflow(serial)
        X = self.conv_UpSampling(serial)
        
        return X

# %%
class context_flow(tf.keras.layers.Layer):    
    def __init__(self, name="context_flow"):
        super().__init__(name=name)
        self.conv_concat = Concatenate(axis = -1, name='concat')
        self.conv_avg_pool = AveragePooling2D(pool_size=(2, 2),strides=(2,2),padding='valid')
        self.conv_3 = Conv2D(64, (3,3),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_3_1 = Conv2D(64, (3,3),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        
        self.conv_1 = Conv2D(64, (1,1),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_act = Activation('relu')
        self.conv_1_1 = Conv2D(64, (1,1),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        
        self.conv_sigmoid = Activation('sigmoid')
        self.conv_mutiply = Multiply()
        self.conv_add = Add()
        self.conv_UpSampling = UpSampling2D(size=(2, 2), interpolation='bilinear')
        
    def call(self, X):
        # here X will a list of two elements 
        INP, FLOW = X[0], X[1] 
        # implement the context flow as mentioned in the above cell
        concat = self.conv_concat([INP,FLOW])
        avg_pool = self.conv_avg_pool(concat)

        conv3 = self.conv_3(avg_pool)
#         print('conv 3: '+str(conv3.shape))
        conv3 = self.conv_3_1(conv3)
        
        conv1 = self.conv_1(conv3)
        conv_act = self.conv_act(conv1)
        conv1 = self.conv_1_1(conv_act)
        sigmoid = self.conv_sigmoid(conv1)
        multi = self.conv_mutiply([conv3,sigmoid])
        add = self.conv_add([conv3,multi])
        X = self.conv_UpSampling(add)
 
        return X

# %% [markdown]
# * As shown in the above architecture we will be having 4 context flows
# * if you have implemented correctly all the shapes of Global Flow, and 3 context flows will have the same dimension
# * the output of these 4 modules will be <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/Add">added</a> to get the same output matrix
# <img src='https://i.imgur.com/Bu63AAA.png' width="400">
#  * The output of after the sum, will be sent to the <strong>Feature selection module $FSM$</strong>
#
# * Example:
#     * if the shapes of GF, CF1, CF2, CF3 are (64,64,32), (64,64,32), (64,64,32), (64,64,32), (64,64,32) respectivly then after the sum we will be getting (64,64,32), which will be passed to the next module.
#
# <strong>Feature selection module</strong>:
#
# * As part of the FSM we will be applying a conv layer (3,3) with the padding="same" so that the output and input will have same shapes
# * Let call the output as X
# * Pass the X to global pooling which results the matrix (#, 1, 1, number_of_channels)
# * Apply $1*1$ conv layer, after the pooling
# * the output of the $1*1$ conv layer will be passed to the Batch normalization layer, followed by Sigmoid activation function.
# * we will be having the output matrix of shape (#, 1, 1, number_of_channels) lets call it 'Y'
# * <strong>we can interpret this as attention mechanisum, i.e for each channel we will having a weight</strong>
# * the dimension of X (#, w, h, k) and output above steps Y is (#, 1, 1, k) i.e we need to multiply each channel of X will be <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/Multiply">multiplied</a> with corresponding channel of Y
# * After creating the weighted channel map we will be doing upsampling such that it will double the height and width.
# * apply <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D">upsampling</a> with bilinear pooling as interpolation technique
#
# * <font color="red">Example</font>:
#     * Assume the matrix shape of the input is (64,64,32) then after upsampling it will be (128,128,32)

# %%
class fsm(tf.keras.layers.Layer):    
    def __init__(self, name="feature_selection"):
        super().__init__(name=name)
        self.conv_3 = Conv2D(32, (3,3),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_global_pool = GlobalAveragePooling2D()
        self.conv_global_reshape = Reshape((1,1,32))
        self.conv_1 = Conv2D(32, (1,1),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_bn = BatchNormalization(axis=1)
        self.conv_sigmoid = Activation('sigmoid')
        self.conv_multiply = Multiply()
        self.conv_UpSampling = UpSampling2D(size=(2, 2), interpolation='bilinear')
        
    def call(self, X):
        # implement the FSM modules based on image in the above cells
        conv3 = self.conv_3(X)
        global_pool = self.conv_global_pool(conv3)
        global_reshape = Reshape((1,1,32))(global_pool)
        conv1 = self.conv_1(global_reshape)
        bn = self.conv_bn(conv1)
        sigmoid = self.conv_sigmoid(bn)
        FSM_Conv_T = Multiply()([conv3,sigmoid])
        FSM_Conv_T = self.conv_UpSampling(FSM_Conv_T)
        return FSM_Conv_T

# %% [markdown]
# * <b>Adapted Global Convolutional Network (AGCN)</b>:
#     <img src="https://i.imgur.com/QNB8RmV.png" width="300">
#
#     * AGCN will get the input from the output of the "conv block" of $C_1$
#
#     * In all the above layers we will be using the padding="same" and stride=(1,1)
#
#     * so that we can have the input and output matrices of same size
#
# * <font color="red">Example</font>:
#     * Assume the matrix shape of the input is (128,128,32) then the output it will be (128,128,32)

# %%
class agcn(tf.keras.layers.Layer):    
    def __init__(self, name="global_conv_net"):
        super().__init__(name=name)
        self.conv_a = Conv2D(32, (7,1),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_b = Conv2D(32, (1,7),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_c = Conv2D(32, (7,1),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_d = Conv2D(32, (1,7),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_add1 = Add()
        self.conv_3 = Conv2D(32, (3,3),strides = (1,1),padding="same",kernel_initializer='glorot_uniform',activation='relu')
        self.conv_add2 = Add()
        
    def call(self, X):
        # please implement the above mentioned architecture
        conva = self.conv_a(X)
        conva = self.conv_b(conva)
        
        convb = self.conv_d(X)
        convb = self.conv_c(convb)
        
        add = self.conv_add1([conva,convb])
        
        conv3 = self.conv_3(add)
        
        X = self.conv_add2([add,conv3])
        
        return X

# %% [markdown]
# *     <img src='https://i.imgur.com/prH3Mno.png' width="600">
# * as shown in the architecture, after we get the AGCN it will get concatinated with the FSM output
#
# * If we observe the shapes both AGCN and FSM will have same height and weight
#
# * we will be concatinating both these outputs over the last axis
#
# * The concatinated output will be passed to a conv layers with filters = number of classes in our data set and the activation function = 'relu'
#
# * we will be using padding="same" which results in the same size feature map
#
# * If you observe the shape of matrix, it will be 4x times less than the original image
#
# * to make it equal to the original output shape, we will do 4x times upsampling of rows and columns
#
# * apply <a href="https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D">upsampling</a> with bilinear pooling as interpolation technique
#
# * Finally we will be applying sigmoid activation.
#
# * Example:
#     * Assume the matrix shape of AGCN is (128,128,32)  and FSM is (128,128,32) the concatination will make it (128, 128, 64)
#     * Applying conv layer will make it (128,128,21)
#     * Finally applying upsampling will make it (512, 512, 21)
#     * Applying sigmoid will result in the same matrix (512, 512, 21)

# %%
X_input = Input(shape=(128,128,3))

# Stage 1
X = Conv2D(64, (3, 3), name='conv1', padding="same", kernel_initializer=glorot_uniform(seed=0))(X_input)
X = BatchNormalization(axis=3, name='bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((2, 2), strides=(2, 2))(X)
print(X.shape)
# Out:
# (None, 64, 64, 64)

# %% [markdown]
# * If you observe the arcitecture we are creating a feature map with 2x time less width and height
# * we have written the first stage of the code above.
# * Write the next layers by using the custom layers we have written

# %%
# write the complete architecutre
def CANet_model(input_shape = (256,256,3) , classes = 21): 
    X_input = Input(input_shape) 
    ### Stage 1 ###
    X = Conv2D(64, (3, 3), name='conv1', padding="same", kernel_initializer=glorot_uniform(seed=0))(X_input)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((2, 2), strides=(2, 2))(X)
    ### C1 ###
    conv_C1 = convolutional_block(kernel=3,  filters=[8,8,16], stride=2, name="conv_block_C1")(X)
    conv_indentity_C1 = identity_block(kernel=3,  filters=[8,8,16], name="identity_block_C1")(conv_C1)
    
    ### C2 ###
    conv_C2 = convolutional_block(kernel=3,  filters=[16,16,32], stride=1, name="conv_block_C2")(conv_indentity_C1)
    conv_indentity_C2 = identity_block(kernel=3,  filters=[16,16,32], name="identity_block_C2_1")(conv_C2)
    conv_indentity_C2 = identity_block(kernel=3,  filters=[16,16,32], name="identity_block_C2_2")(conv_indentity_C2)
    
    ### C3 ###
    conv_C3 = convolutional_block(kernel=3,  filters=[32,32,64], stride=1, name="conv_block_C3")(conv_indentity_C2)
    conv_indentity_C3 = identity_block(kernel=3,  filters=[32,32,64], name="identity_block_C3_1")(conv_C3)
    conv_indentity_C3 = identity_block(kernel=3,  filters=[32,32,64], name="identity_block_C3_2")(conv_indentity_C3)
    conv_indentity_C3 = identity_block(kernel=3,  filters=[32,32,64], name="identity_block_C3_3")(conv_indentity_C3)
    
    ### C4 ###
    conv_C4 = convolutional_block(kernel=3,  filters=[64,64,128], stride=1, name="conv_block_C4")(conv_indentity_C3)
    conv_indentity_c4 = identity_block(kernel=3,  filters=[64,64,128], name="identity_block_C4_1")(conv_C4)
    conv_indentity_c4 = identity_block(kernel=3,  filters=[64,64,128], name="identity_block_C4_2")(conv_indentity_c4)
    conv_indentity_c4 = identity_block(kernel=3,  filters=[64,64,128], name="identity_block_C4_3")(conv_indentity_c4)
    conv_indentity_c4 = identity_block(kernel=3,  filters=[64,64,128], name="identity_block_C4_4")(conv_indentity_c4)
    
    ### global flow ###
    conv_GF = global_flow()(conv_indentity_c4)
    
    ### context flow ###
    conv_CF1 = context_flow(name = "Context_Flow_1")([conv_indentity_c4,conv_GF])
    conv_CF2 = context_flow(name = "Context_Flow_2")([conv_indentity_c4,conv_CF1])
    conv_CF3 = context_flow(name = "Context_Flow_3")([conv_indentity_c4,conv_CF2])
    
    ### Add global flow and context flow ###
    conv_gf_cf_add = Add()([conv_GF,conv_CF1,conv_CF2,conv_CF3])
    
    ### Feature Selection module ###
    conv_fsm = fsm(name = "feature_selection")(conv_gf_cf_add)
    
    ### AGCN ###
    conv_agcn = agcn(name = "adapted_gcn")(X)
    
    ### Concatenating agcn and fsm ###
    concat_agcn_fsm = concatenate([conv_agcn,conv_fsm],axis=-1)
    
    ### 3*3 convolution ###
    conv_final = Conv2D(classes, (3, 3), activation = 'relu', padding = 'same',name='conv_final')(concat_agcn_fsm)
    conv_final_bn = X = BatchNormalization(axis=3, name='bn_conv_final')(conv_final)
    conv_final_act = Activation('relu')(conv_final_bn)
    
    ### Upsampling to get 256,256,21 ###
    conv_upsampling = UpSampling2D(size=(2, 2), interpolation='bilinear')(conv_final_act)
    
    X = Activation('softmax')(conv_upsampling)
    model = Model(inputs = X_input, outputs = X) 
    return model
X_input = (256,256,3)
model_CANet = CANet_model(X_input , 21)

model_CANet.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 256, 256, 64) 1792        input_5[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 256, 256, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 256, 256, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_142[0][0]
# __________________________________________________________________________________________________
# conv_block_C1 (convolutional_bl (None, 64, 64, 16)   10672       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# identity_block_C1 (identity_blo (None, 64, 64, 16)   992         conv_block_C1[0][0]
# __________________________________________________________________________________________________
# conv_block_C2 (convolutional_bl (None, 64, 64, 32)   8160        identity_block_C1[0][0]
# __________________________________________________________________________________________________
# identity_block_C2_1 (identity_b (None, 64, 64, 32)   3648        conv_block_C2[0][0]
# __________________________________________________________________________________________________
# identity_block_C2_2 (identity_b (None, 64, 64, 32)   3648        identity_block_C2_1[0][0]
# __________________________________________________________________________________________________
# conv_block_C3 (convolutional_bl (None, 64, 64, 64)   31680       identity_block_C2_2[0][0]
# __________________________________________________________________________________________________
# identity_block_C3_1 (identity_b (None, 64, 64, 64)   13952       conv_block_C3[0][0]
# __________________________________________________________________________________________________
# identity_block_C3_2 (identity_b (None, 64, 64, 64)   13952       identity_block_C3_1[0][0]
# __________________________________________________________________________________________________
# identity_block_C3_3 (identity_b (None, 64, 64, 64)   13952       identity_block_C3_2[0][0]
# __________________________________________________________________________________________________
# conv_block_C4 (convolutional_bl (None, 64, 64, 128)  124800      identity_block_C3_3[0][0]
# __________________________________________________________________________________________________
# identity_block_C4_1 (identity_b (None, 64, 64, 128)  54528       conv_block_C4[0][0]
# __________________________________________________________________________________________________
# identity_block_C4_2 (identity_b (None, 64, 64, 128)  54528       identity_block_C4_1[0][0]
# __________________________________________________________________________________________________
# identity_block_C4_3 (identity_b (None, 64, 64, 128)  54528       identity_block_C4_2[0][0]
# __________________________________________________________________________________________________
# identity_block_C4_4 (identity_b (None, 64, 64, 128)  54528       identity_block_C4_3[0][0]
# __________________________________________________________________________________________________
# global_flow (global_flow)       (None, 64, 64, 64)   45188       identity_block_C4_4[0][0]
# __________________________________________________________________________________________________
# Context_Flow_1 (context_flow)   (None, 64, 64, 64)   155904      identity_block_C4_4[0][0]
#                                                                  global_flow[0][0]
# __________________________________________________________________________________________________
# Context_Flow_2 (context_flow)   (None, 64, 64, 64)   155904      identity_block_C4_4[0][0]
#                                                                  Context_Flow_1[0][0]
# __________________________________________________________________________________________________
# Context_Flow_3 (context_flow)   (None, 64, 64, 64)   155904      identity_block_C4_4[0][0]
#                                                                  Context_Flow_2[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 64, 64, 64)   0           global_flow[0][0]
#                                                                  Context_Flow_1[0][0]
#                                                                  Context_Flow_2[0][0]
#                                                                  Context_Flow_3[0][0]
# __________________________________________________________________________________________________
# adapted_gcn (agcn)              (None, 128, 128, 32) 52384       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# feature_selection (fsm)         (None, 128, 128, 32) 19524       add_56[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 64) 0           adapted_gcn[0][0]
#                                                                  feature_selection[0][0]
# __________________________________________________________________________________________________
# conv_final (Conv2D)             (None, 128, 128, 21) 12117       concatenate_1[0][0]
# __________________________________________________________________________________________________
# bn_conv_final (BatchNormalizati (None, 128, 128, 21) 84          conv_final[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 128, 128, 21) 0           bn_conv_final[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 256, 256, 21) 0           activation_211[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 256, 256, 21) 0           up_sampling2d_13[0][0]
# ==================================================================================================
# Total params: 1,042,625
# Trainable params: 1,037,875
# Non-trainable params: 4,750
# __________________________________________________________________________________________________

# %%
import segmentation_models as sm
from segmentation_models.metrics import iou_score
# from segmentation_models import Unet
from tensorflow.keras.optimizers import Adam
from keras.optimizers import TFOptimizer
optim = tf.keras.optimizers.Adam(lr = 1e-4)
# optim= TFOptimizer(adamW)
# optim.lr = learning_rate

focal_loss = sm.losses.cce_dice_loss

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss 
# or total_loss = sm.losses.categorical_focal_dice_loss 

model_CANet.compile(optimizer=optim, loss = focal_loss, metrics=[iou_score])

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint('./best_CANet_model_test.h5', save_weights_only=True, save_best_only=True, \
                                       mode='min', monitor='val_iou_score'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_iou_score', min_lr=0.000001,patience=2),
]

# %%
history_CANet = model_CANet.fit_generator(train_dataloader, steps_per_epoch=len(train_dataloader), epochs=300,\
                              validation_data=test_dataloader,callbacks=callbacks )
# Out:
# WARNING:tensorflow:From <ipython-input-32-033be0ad4b57>:2: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# C:\Users\divya\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# Epoch 1/300
# 400/400 [==============================] - 275s 687ms/step - loss: 1.0489 - iou_score: 0.0407 - val_loss: 1.0463 - val_iou_score: 0.0434
# Epoch 2/300
# 400/400 [==============================] - 266s 664ms/step - loss: 1.0086 - iou_score: 0.0562 - val_loss: 1.0170 - val_iou_score: 0.0548
# Epoch 3/300
# 400/400 [==============================] - 274s 685ms/step - loss: 0.9919 - iou_score: 0.0642 - val_loss: 0.9911 - val_iou_score: 0.0649
# Epoch 4/300
# 400/400 [==============================] - 321s 802ms/step - loss: 0.9796 - iou_score: 0.0703 - val_loss: 0.9746 - val_iou_score: 0.0732
# Epoch 5/300
# 400/400 [==============================] - 275s 686ms/step - loss: 0.9780 - iou_score: 0.0710 - val_loss: 0.9818 - val_iou_score: 0.0682
# Epoch 6/300
# 400/400 [==============================] - 285s 711ms/step - loss: 0.9757 - iou_score: 0.0721 - val_loss: 0.9758 - val_iou_score: 0.0720
# Epoch 7/300
# 400/400 [==============================] - 279s 696ms/step - loss: 0.9754 - iou_score: 0.0724 - val_loss: 0.9740 - val_iou_score: 0.0727
# Epoch 8/300
# 400/400 [==============================] - 283s 707ms/step - loss: 0.9749 - iou_score: 0.0724 - val_loss: 0.9700 - val_iou_score: 0.0740
# Epoch 9/300
#  30/400 [=>............................] - ETA: 3:31 - loss: 0.9718 - iou_score: 0.0753
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-033be0ad4b57> in <module>
#       1 history_CANet = model_CANet.fit_generator(train_dataloader, steps_per_epoch=len(train_dataloader), epochs=300,\
# ----> 2                               validation_data=test_dataloader,callbacks=callbacks )
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1827         use_multiprocessing=use_multiprocessing,
#    1828         shuffle=shuffle,
# -> 1829         initial_epoch=initial_epoch)
#    1830
#    1831   @deprecation.deprecated(
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\keras\engine\training.py in train_function(iterator)
#     804       def train_function(iterator):
#     805         """Runs a training execution with one step."""
# --> 806         return step_function(self, iterator)
#     807
#     808     else:
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\keras\engine\training.py in step_function(model, iterator)
#     793         return outputs
#     794
# --> 795       data = next(iterator)
#     796       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     797       outputs = reduce_per_replica(
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __next__(self)
#     734
#     735   def __next__(self):  # For Python 3 compatibility
# --> 736     return self.next()
#     737
#     738   def _next_internal(self):
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in next(self)
#     770   def next(self):
#     771     try:
# --> 772       return self._next_internal()
#     773     except errors.OutOfRangeError:
#     774       raise StopIteration
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _next_internal(self)
#     756             self._iterator_resource,
#     757             output_types=self._flat_output_types,
# --> 758             output_shapes=self._flat_output_shapes)
#     759
#     760       try:
#
# ~\anaconda3\envs\gpu_test\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2605         _ctx._context_handle, tld.device_name, "IteratorGetNext", name,
#    2606         tld.op_callbacks, iterator, "output_types", output_types,
# -> 2607         "output_shapes", output_shapes)
#    2608       return _result
#    2609     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history_CANet.history['iou_score'])
plt.plot(history_CANet.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history_CANet.history['loss'])
plt.plot(history_CANet.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6296\4277199147.py in <module>
#       2 plt.figure(figsize=(30, 5))
#       3 plt.subplot(121)
# ----> 4 plt.plot(history_CANet.history['iou_score'])
#       5 plt.plot(history_CANet.history['val_iou_score'])
#       6 plt.title('Model iou_score')
#
# NameError: name 'history_CANet' is not defined

# %%
tf.keras.utils.plot_model(
    model_CANet, to_file='model_CANet.png', show_shapes=True, show_layer_names=True,
    rankdir='TB')

# %% [markdown]
# ### Usefull tips:
# * use "interpolation=cv2.INTER_NEAREST" when you are resizing the image, so that it won't mess with the number of classes
# * keep the images in the square shape like $256*256$ or $512*512$
# * Carefull when you are converting the (W, H) output image into (W, H, Classes)
# * Even for the canet, use the segmentation model's losses and the metrics
# * The goal of this assignment is make you familier in with computer vision problems, image preprocessing, building complex architectures and implementing research papers, so that in future you will be very confident in industry
# * you can use the tensorboard logss to see how is yours model's training happening
# * use callbacks that you have implemented in previous assignments

# %% [markdown]
# ### Things to keep in mind

# %% [markdown]
# * You need to train  above built model and plot the train and test losses.
# * Make sure there is no overfitting, you are free play with the identity blocks in C1, C2, C3, C4
# * before we apply the final sigmoid activation, you can add more conv layers or BN or dropouts etc
# * you are free to use any other optimizer or learning rate or weights init or regularizations
